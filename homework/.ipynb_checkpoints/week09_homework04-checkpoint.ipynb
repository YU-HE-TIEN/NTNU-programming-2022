# %% [markdown]
# ## 文字探勘作業四

# %%
#引入套件
import jieba
import jieba.analyse
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
# 讀取從pandas的結構化資料，但內文的句子尚未擷取出合適斷詞
orgdata = pd.read_csv(r"C:\Users\tien\Documents\GitHub\PL\file\W9\觀光景點資料.csv")

# %%
orgdata.head()
# Out:
#    Id             Name Zone  \
# 0   0      宏亞食品巧克力觀光工廠  NaN
# 1   1          台灣金屬創意館  NaN
# 2   2  臺灣菸酒(股)公司林口觀光酒廠  NaN
# 3   3          水璉、牛山海岸  NaN
# 4   4              石梯坪  NaN
#
#                                          Description                Tel  \
# 0  巧克力共和國是一座以巧克力為主題的觀光工廠，建築設計、館內主題設計皆以巧克力為主題，這裡也提...      886-3-3656555
# 1  台灣金屬創意館為第一座金屬造型觀光工廠，來這裡可讓大家看到並觸摸到金屬柔軟的一面，館區內充滿...  886-6-2036735#245
# 2  林口酒廠為北部地區產能最大、設備最現代化的清酒、紅麴葡萄酒生產工廠。廠內有產品推廣中心，開放...  886-3-3283001#430
# 3  水璉位在花蓮縣壽豐鄉海濱，為阿美族世居之地，早在3,500年前即有繩紋陶文化之先民居住於此。...      886-3-8601400
# 4  石梯坪位在花蓮縣豐濱鄉石梯灣的南側，整個區域是一個面積極大的海岸階地，海蝕地形十分發達，海蝕...      886-3-8781452
#
#                 Add Region Town  \
# 0     桃園縣八德市建國路386號    桃園市  八德區
# 1    台南市永康區永科環路598號    臺南市  永康區
# 2     桃園縣龜山鄉文化一路55號    桃園市  龜山區
# 3  花蓮縣974壽豐鄉牛山39之5號    花蓮縣  壽豐鄉
# 4   花蓮縣977豐濱鄉石梯坪52號    花蓮縣  豐濱鄉
#
#                                       Travellinginfo  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  南下：於花蓮火車站前的花蓮客運，搭乘往豐濱、成功方向的海線班車，經花蓮大橋，約40～50分鐘...
# 4  南下：由花蓮火車站前搭往成功、靜浦或台東等地的花蓮、鼎東客運海線班車，在石梯坪下車。 北上：...
#
#                                       Opentime  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                每日10:00-18:00
# 4  全天候開放露營電話預約時間：09:00~18:00電話：0922-211336 呂先生
#
#                                  Picdescribe1          Px         Py Orgclass  \
# 0                                         NaN  121.297187  24.943325     觀光工廠
# 1                                         NaN  120.275724  23.045063     觀光工廠
# 2                                         NaN  121.375231  25.056168     觀光工廠
# 3  當整個東海岸被層層的消坡塊鎖住時，綿延兩公里長的水璉牛山，卻散發出難能可貴的自然光采  121.569400  23.763440      NaN
# 4                             宛如鬼斧神工般的石梯坪海蝕地形  121.511730  23.485250      NaN
#
#                                           Ticketinfo  \
# 0                                            收費方式請電洽
# 1                                            收費方式請電洽
# 2                                            收費方式請電洽
# 3                               牛山呼庭園區需付50元門票，可抵用飲品。
# 4  大型車：假日200元、非假日170元小型車：假日60元、非假日50元機車：假日20元、非假日15元
#
#                                              Remarks         Keyword
# 0                                    詳細參觀訊息請逕洽廠商網站說明  桃園，宏亞，巧克力，觀光工廠
# 1                                    詳細參觀訊息請逕洽廠商網站說明   台南，志鋼，金屬，觀光工廠
# 2                                    詳細參觀訊息請逕洽廠商網站說明   林口，菸酒，酒廠，觀光工廠
# 3                     東海岸的石頭雖美，但請切勿撿取。走米棧古道，記得帶瓶水解渴。             NaN
# 4  1.石梯坪沒有遮陽設施，海邊日照強，要做好防曬；裝備也要齊全，除了遮陽的帽子、長褲、長袖，解...             NaN

# %%
orgdata.index
# Out:
# RangeIndex(start=0, stop=5676, step=1)

# %%
# 結巴套件的練習，和檔案內容無關
documents = ['過失責任車禍賠償']
# 精確模式
for sentence in documents:
    seg_list = jieba.cut(sentence)
    print('/'.join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\tien\AppData\Local\Temp\jieba.cache
# Loading model cost 0.551 seconds.
# Prefix dict has been built successfully.
# 過失責/任車/禍/賠償

# %%
# test
for s in documents:
    seg_list = jieba.cut(s)
    print(seg_list)
    print(' '.join(seg_list))
# Out:
# <generator object Tokenizer.cut at 0x000001F465765890>
# 過失責 任車 禍 賠償

# %%
jieba.load_userdict(r"C:\Users\tien\Documents\GitHub\PL\file\W9\test_dict.txt")

for sentence in documents:
    seg_list = jieba.cut(sentence)
    print(' '.join(seg_list))
# Out:
# 過失 責任 車禍 賠償

# %%
orgdata['seg'] = ""
orgdata.head()
# Out:
#    Id             Name Zone  \
# 0   0      宏亞食品巧克力觀光工廠  NaN
# 1   1          台灣金屬創意館  NaN
# 2   2  臺灣菸酒(股)公司林口觀光酒廠  NaN
# 3   3          水璉、牛山海岸  NaN
# 4   4              石梯坪  NaN
#
#                                          Description                Tel  \
# 0  巧克力共和國是一座以巧克力為主題的觀光工廠，建築設計、館內主題設計皆以巧克力為主題，這裡也提...      886-3-3656555
# 1  台灣金屬創意館為第一座金屬造型觀光工廠，來這裡可讓大家看到並觸摸到金屬柔軟的一面，館區內充滿...  886-6-2036735#245
# 2  林口酒廠為北部地區產能最大、設備最現代化的清酒、紅麴葡萄酒生產工廠。廠內有產品推廣中心，開放...  886-3-3283001#430
# 3  水璉位在花蓮縣壽豐鄉海濱，為阿美族世居之地，早在3,500年前即有繩紋陶文化之先民居住於此。...      886-3-8601400
# 4  石梯坪位在花蓮縣豐濱鄉石梯灣的南側，整個區域是一個面積極大的海岸階地，海蝕地形十分發達，海蝕...      886-3-8781452
#
#                 Add Region Town  \
# 0     桃園縣八德市建國路386號    桃園市  八德區
# 1    台南市永康區永科環路598號    臺南市  永康區
# 2     桃園縣龜山鄉文化一路55號    桃園市  龜山區
# 3  花蓮縣974壽豐鄉牛山39之5號    花蓮縣  壽豐鄉
# 4   花蓮縣977豐濱鄉石梯坪52號    花蓮縣  豐濱鄉
#
#                                       Travellinginfo  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  南下：於花蓮火車站前的花蓮客運，搭乘往豐濱、成功方向的海線班車，經花蓮大橋，約40～50分鐘...
# 4  南下：由花蓮火車站前搭往成功、靜浦或台東等地的花蓮、鼎東客運海線班車，在石梯坪下車。 北上：...
#
#                                       Opentime  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                每日10:00-18:00
# 4  全天候開放露營電話預約時間：09:00~18:00電話：0922-211336 呂先生
#
#                                  Picdescribe1          Px         Py Orgclass  \
# 0                                         NaN  121.297187  24.943325     觀光工廠
# 1                                         NaN  120.275724  23.045063     觀光工廠
# 2                                         NaN  121.375231  25.056168     觀光工廠
# 3  當整個東海岸被層層的消坡塊鎖住時，綿延兩公里長的水璉牛山，卻散發出難能可貴的自然光采  121.569400  23.763440      NaN
# 4                             宛如鬼斧神工般的石梯坪海蝕地形  121.511730  23.485250      NaN
#
#                                           Ticketinfo  \
# 0                                            收費方式請電洽
# 1                                            收費方式請電洽
# 2                                            收費方式請電洽
# 3                               牛山呼庭園區需付50元門票，可抵用飲品。
# 4  大型車：假日200元、非假日170元小型車：假日60元、非假日50元機車：假日20元、非假日15元
#
#                                              Remarks         Keyword seg
# 0                                    詳細參觀訊息請逕洽廠商網站說明  桃園，宏亞，巧克力，觀光工廠
# 1                                    詳細參觀訊息請逕洽廠商網站說明   台南，志鋼，金屬，觀光工廠
# 2                                    詳細參觀訊息請逕洽廠商網站說明   林口，菸酒，酒廠，觀光工廠
# 3                     東海岸的石頭雖美，但請切勿撿取。走米棧古道，記得帶瓶水解渴。             NaN
# 4  1.石梯坪沒有遮陽設施，海邊日照強，要做好防曬；裝備也要齊全，除了遮陽的帽子、長褲、長袖，解...             NaN

# %%
jieba.analyse.set_stop_words(r"C:\Users\tien\Documents\GitHub\PL\file\W9\stopwords.txt")
index = 0
for documents in orgdata['Description']:
    seg_list = jieba.analyse.extract_tags(str(documents), 150)
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1
# Out:
# C:\Users\tien\AppData\Local\Temp\ipykernel_18728\3832514975.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
orgdata['seg']
# Out:
# 0       [巧克力, 為主題, 設計, 國是, 觀光, 工廠, 建築, 內主題, 豐富, 相關, 知識...
# 1       [金屬, 觀光, 台灣, 創意館, 工廠, 並觸, 柔軟, 館區, 充滿, 各種, 驚奇, ...
# 2       [酒廠, 地區, 產能, 設備, 現代化, 生產, 工廠, 廠內, 有產品, 推廣, 開放參...
# 3       [阿美族, 水璉位, 花蓮縣, 壽豐鄉, 海濱, 500, 繩紋陶, 水璉, 海灘, Hud...
# 4       [石梯, 海蝕, 活動, 露營區, 此處, 電話, 03, 阿美族, 坪位, 花蓮縣, 豐濱...
#                               ...
# 5671                                                [nan]
# 5672                                                [nan]
# 5673                                                [nan]
# 5674                                                [nan]
# 5675                                                [nan]
# Name: seg, Length: 5676, dtype: object

# %%
Counter(orgdata['Region']).keys()
# Out:
# dict_keys(['桃園市', '臺南市', '花蓮縣', '臺東縣', '澎湖縣', '屏東縣', '連江縣', '南投縣', '苗栗縣', '新竹縣', '臺中市', '彰化縣', '宜蘭縣', '嘉義縣', '高雄市', '新北市', '基隆市', '雲林縣', '金門縣', '新竹市', '嘉義市', '臺北市'])

# %%
show_key = pd.DataFrame(Counter(orgdata['Region']).keys())
show_values = pd.DataFrame(Counter(orgdata['Region']).values())
df = [show_key, show_values]

# %%
result = pd.concat(df, axis=1)
result.columns = ['Region', 'Number of attractions']
result.head()
# Out:
#   Region  Number of attractions
# 0    桃園市                    262
# 1    臺南市                    489
# 2    花蓮縣                    147
# 3    臺東縣                    286
# 4    澎湖縣                    304

# %%
import plotly.express as px
import pandas as pd

px.bar(result, x='Region', y='Number of attractions', title='Number of attractions in all counties in Taiwan')
# Out:
# <div>                            <div id="12c1f87b-f4c6-49c6-a4be-1fc4e6cb4089" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12c1f87b-f4c6-49c6-a4be-1fc4e6cb4089")) {                    Plotly.newPlot(                        "12c1f87b-f4c6-49c6-a4be-1fc4e6cb4089",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>Number of attractions=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u6843\u5712\u5e02","\u81fa\u5357\u5e02","\u82b1\u84ee\u7e23","\u81fa\u6771\u7e23","\u6f8e\u6e56\u7e23","\u5c4f\u6771\u7e23","\u9023\u6c5f\u7e23","\u5357\u6295\u7e23","\u82d7\u6817\u7e23","\u65b0\u7af9\u7e23","\u81fa\u4e2d\u5e02","\u5f70\u5316\u7e23","\u5b9c\u862d\u7e23","\u5609\u7fa9\u7e23","\u9ad8\u96c4\u5e02","\u65b0\u5317\u5e02","\u57fa\u9686\u5e02","\u96f2\u6797\u7e23","\u91d1\u9580\u7e23","\u65b0\u7af9\u5e02","\u5609\u7fa9\u5e02","\u81fa\u5317\u5e02"],"xaxis":"x","y":[262,489,147,286,304,296,100,280,182,205,367,309,146,397,282,587,4,260,209,93,70,401],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...

# %%
show_sub = orgdata['Region']=='花蓮縣'
subdata = orgdata[show_sub]
subdata
# Out:
#         Id           Name Zone  \
# 3        3        水璉、牛山海岸  NaN
# 4        4            石梯坪  NaN
# 5        5            長虹橋  NaN
# 6        6           北回歸線  NaN
# 26      26         花蓮遊客中心  NaN
# ...    ...            ...  ...
# 3270  3270         龍泉親水公園  NaN
# 3271  3271         郭子究音樂館  NaN
# 3272  3272           七七高地  NaN
# 3273  3273  將軍府（美崙溪畔日式宿舍）  NaN
# 3274  3274        洄瀾灣開心農場  NaN
#
#                                             Description            Tel  \
# 3     水璉位在花蓮縣壽豐鄉海濱，為阿美族世居之地，早在3,500年前即有繩紋陶文化之先民居住於此。...  886-3-8601400
# 4     石梯坪位在花蓮縣豐濱鄉石梯灣的南側，整個區域是一個面積極大的海岸階地，海蝕地形十分發達，海蝕...  886-3-8781452
# 5     長虹橋橫跨秀姑巒溪，連接靜浦與港口兩聚落，亦是秀姑巒溪泛舟的終點站；橋分新舊兩座橋，新橋採鮮...  886-3-8671326
# 6     北回歸線標碑位在北緯23.5度，是太陽直射地球的北界，也是亞熱帶與熱帶的分界。靜浦的北回歸線...  886-3-8671326
# 26    沿著台11線走，順著蜿蜒的道路來到東海岸風景區最北端的花蓮遊客中心，坐落於山坡上的遊客中心，...  886-3-8671326
# ...                                                 ...            ...
# 3270  隸屬生態親水公園的龍泉親水公園占地約為一千二佰坪，位置坐落於佳山基地聯絡道旁的農地，舊時因灌...  886-3-8267223
# 3271  「郭子究音樂文化館」規劃主軸有二個方向，其一是以「郭子究音樂文化館」展演、經營、體驗等相關設...  886-3-8235466
# 3272  過去做為軍事要塞的七七高地，是個極少數遊客會去的地方，地勢不高，但景色絕美，是一處能夠環景3...  886-3-8227171
# 3273  美崙溪畔日式宿舍位於花蓮市中正橋旁，這個宿舍群在日本時代原本是提供花蓮港分屯大隊軍官住宿的宿...  886-3-8227121
# 3274  台開心農場騎馬，餵食動物 (梅花鹿、孔雀、羊、公雞、天鵝等)都很有趣，限定季節還會有整片向日...  886-3-8420889
#
#                         Add Region Town  \
# 3          花蓮縣974壽豐鄉牛山39之5號    花蓮縣  壽豐鄉
# 4           花蓮縣977豐濱鄉石梯坪52號    花蓮縣  豐濱鄉
# 5        花蓮縣977豐濱鄉台11線68公里處    花蓮縣  豐濱鄉
# 6      花蓮縣977豐濱鄉台11線70.5公里處    花蓮縣  豐濱鄉
# 26         花蓮縣974壽豐鄉鹽寮村大坑5號    花蓮縣  壽豐鄉
# ...                     ...    ...  ...
# 3270              花蓮縣新城鄉佳林村    花蓮縣  新城鄉
# 3271           花蓮市民權七街1巷10號    花蓮縣  花蓮市
# 3272  花蓮縣壽豐鄉台11線6.5公里處產業道路上    花蓮縣  壽豐鄉
# 3273           花蓮市中正路622巷6號    花蓮縣  花蓮市
# 3274        花蓮縣吉安鄉華中路11-10號    花蓮縣  吉安鄉
#
#                                          Travellinginfo  \
# 3     南下：於花蓮火車站前的花蓮客運，搭乘往豐濱、成功方向的海線班車，經花蓮大橋，約40～50分鐘...
# 4     南下：由花蓮火車站前搭往成功、靜浦或台東等地的花蓮、鼎東客運海線班車，在石梯坪下車。 北上：...
# 5     南下：由花蓮火車站前搭往成功、靜浦或台東等地的花蓮、鼎東客運海線班車，在長虹橋站下車，再依指...
# 6     南下：由花蓮火車站前搭往成功、靜浦或台東等地的花蓮、鼎東客運海線班車，在北回歸線標碑下車。北...
# 26    南下：於花蓮火車站前的花蓮客運，搭乘往豐濱、靜浦，或是台東方向的海線班車，抵達遠雄海洋公園後...
# ...                                                 ...
# 3270                                                NaN
# 3271                                                NaN
# 3272                                                NaN
# 3273                                                NaN
# 3274                                                NaN
#
#                                                Opentime  \
# 3                                         每日10:00-18:00
# 4           全天候開放露營電話預約時間：09:00~18:00電話：0922-211336 呂先生
# 5                                                 全天候開放
# 6                                                  全年開放
# 26    星期日: 08:30 - 17:00星期一: 08:30 - 17:00星期二: 08:30...
# ...                                                 ...
# 3270                                        08:00-17:30
# 3271                                        10:00-16:30
# 3272                                              全天候開放
# 3273                                              全天候開放
# 3274                                        08:00-17:30
#
#                                     Picdescribe1          Px         Py  \
# 3     當整個東海岸被層層的消坡塊鎖住時，綿延兩公里長的水璉牛山，卻散發出難能可貴的自然光采  121.569400  23.763440
# 4                                宛如鬼斧神工般的石梯坪海蝕地形  121.511730  23.485250
# 5                         橫跨秀姑巒溪，連接靜浦與港口兩聚落的新長虹橋  121.489040  23.468450
# 6                                         北回歸線標碑  121.496170  23.451410
# 26                                      鳥瞰花蓮遊客中心  121.602410  23.904550
# ...                                          ...         ...        ...
# 3270                                         NaN  121.603109  24.017313
# 3271                                         NaN  121.624659  23.987299
# 3272                                         NaN  121.607620  23.932820
# 3273                                         NaN  121.613226  23.980629
# 3274                                         NaN  121.598720  23.937236
#
#      Orgclass                                         Ticketinfo  \
# 3         NaN                               牛山呼庭園區需付50元門票，可抵用飲品。
# 4         NaN  大型車：假日200元、非假日170元小型車：假日60元、非假日50元機車：假日20元、非假日15元
# 5         NaN                                                 免費
# 6         NaN                                                 免費
# 26        NaN                                                NaN
# ...       ...                                                ...
# 3270      NaN                                                NaN
# 3271      NaN                                                NaN
# 3272      NaN                                                NaN
# 3273      NaN                                                NaN
# 3274      NaN                                                NaN
#
#                                                 Remarks Keyword  \
# 3                        東海岸的石頭雖美，但請切勿撿取。走米棧古道，記得帶瓶水解渴。     NaN
# 4     1.石梯坪沒有遮陽設施，海邊日照強，要做好防曬；裝備也要齊全，除了遮陽的帽子、長褲、長袖，解...     NaN
# 5                                                   NaN     NaN
# 6     1.北回歸線位於北緯23.5度，它是太陽直射地球的北界；換言之，夏至時太陽沿著此緯度線東昇西...     NaN
# 26                                                  NaN     NaN
# ...                                                 ...     ...
# 3270                                                NaN     NaN
# 3271                                                NaN     NaN
# 3272                                                NaN     NaN
# 3273                                                NaN     NaN
# 3274                                                NaN     NaN
#
#                                                     seg
# 3     [阿美族, 水璉位, 花蓮縣, 壽豐鄉, 海濱, 500, 繩紋陶, 水璉, 海灘, Hud...
# 4     [石梯, 海蝕, 活動, 露營區, 此處, 電話, 03, 阿美族, 坪位, 花蓮縣, 豐濱...
# 5     [姑巒, 白如玉, 泛舟, 大岩, 步道, 橋橫, 跨秀, 連接, 靜浦, 終點, 橋分, ...
# 6     [北回, 歸線, 標碑, 北緯, 23.5, 太陽, 亞熱帶, 熱帶, 靜浦, 11, 70...
# 26    [海岸, 中心, 花蓮遊客, 遊客, 山坡, 展示室, 太平洋, 沿著台, 11, 順著, ...
# ...                                                 ...
# 3270  [親水公園, 空間, 水源, 一千二, 隸屬, 生態, 龍泉, 佰坪, 佳山, 聯絡, 農地...
# 3271  [展演, 郭子究, 音樂, 經營, 體驗, 空間, 規劃, 主軸有, 二個, 相關, 設施,...
# 3272  [七七, 高地, 過去, 軍事, 極少, 數遊, 客會, 地勢, 絕美, 環景, 360, ...
# 3273  [宿舍, 營所通, 中正, 溪畔, 美崙, 花蓮市, 橋旁, 這個, 群在, 時代, 花蓮港...
# 3274  [農場, 有趣, 星巴克, 台開心, 騎馬, 食動物, 公雞, 天鵝等, 季節, 還會, 參...
#
# [147 rows x 18 columns]

# %%
show_sub
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 5671    False
# 5672    False
# 5673    False
# 5674    False
# 5675    False
# Name: Region, Length: 5676, dtype: bool

# %%
subdata.to_csv('HW9花蓮縣景點.csv')

# %%
type(subdata['seg'])
# Out:
# pandas.core.series.Series

# %%
subdata_seg_list = subdata['seg'].tolist()
type(subdata_seg_list)
# Out:
# list

# %%
subdata_seg_list
# Out:
# [['阿美族',
#   '水璉位',
#   '花蓮縣',
#   '壽豐鄉',
#   '海濱',
#   '500',
#   '繩紋陶',
#   '水璉',
#   '海灘',
#   'Hudin',
#   '呼定',
#   '牧場',
#   '群相',
#   '豐富',
#   '幾乎',
#   '東部',
#   '縮影',
#   '劃定',
#   '生態',
#   '保護區',
#   '綿延數',
#   '沙灘',
#   '絕佳',
#   '臨海',
#   '樂園',
#   '牛山',
#   '植物',
#   '座落在',
#   '世居',
#   '美景',
#   '意即',
#   '先民',
#   '草地',
#   '海岸',
#   '大片',
#   '之地',
#   '年前',
#   '居住',
#   '秘密',
#   '南方',
#   '公里',
#   '一片',
#   '文化',
#   '自然'],
#  ['石梯',
#   '海蝕',
#   '活動',
#   '露營區',
#   '此處',
#   '電話',
#   '03',
#   '阿美族',
#   '坪位',
#   '花蓮縣',
#   '豐濱',
#   '灣的',
#   '南側',
#   '整個',
#   '區域',
#   '面積',
#   '極大',
#   '階地',
#   '發達',
#   '海蝕溝',
#   '是壺',
#   '穴景觀',
#   '堪稱',
#   '台灣',
#   '遊客',
#   '觀察潮間',
#   '豐富',
#   '生態',
#   '潛水',
#   '選擇',
#   '設備',
#   '捕魚',
#   '豐年',
#   '祭為',
#   '同時',
#   '台灣賞',
#   '8781452',
#   '8781599',
#   '族群',
#   '夜宿',
#   '工作站',
#   '源地',
#   '比比皆是',
#   '珊瑚礁',
#   '隆起',
#   '亦可',
#   '海岸',
#   '主要',
#   '夏天',
#   '地形',
#   '平台',
#   '完善',
#   '尤其',
#   '第一'],
#  ['姑巒',
#   '白如玉',
#   '泛舟',
#   '大岩',
#   '步道',
#   '橋橫',
#   '跨秀',
#   '連接',
#   '靜浦',
#   '終點',
#   '橋分',
#   '新舊',
#   '兩座橋',
#   '新橋',
#   '採鮮艷',
#   '紅色',
#   '橋面',
#   '規劃',
#   '車道',
#   '腳踏車',
#   '專用',
#   '活動',
#   '設置',
#   '觀景台',
#   '橋上',
#   '可遠眺',
#   '奚卜蘭島',
#   '因登島',
#   '島上',
#   '仍維持',
#   '樣貌',
#   '許多潔',
#   '其為',
#   '石潔',
#   '秀姑漱玉',
#   '八座',
#   '原始林',
#   '亮眼',
#   '美名',
#   '俯瞰',
#   '河面',
#   '聚落',
#   '人行',
#   '快慢',
#   '分隔',
#   '巨型',
#   '出海',
#   '石灰岩',
#   '因其',
#   '不易',
#   '港口',
#   '配合',
#   '因而',
#   '得到'],
#  ['北回',
#   '歸線',
#   '標碑',
#   '北緯',
#   '23.5',
#   '太陽',
#   '亞熱帶',
#   '熱帶',
#   '靜浦',
#   '11',
#   '70.5',
#   '途經',
#   '台灣',
#   '東界',
#   '聳立',
#   '遊客',
#   '塔身',
#   '直射',
#   '北界',
#   '分界',
#   '太平洋',
#   '白色',
#   '目光',
#   '地球',
#   '吸引',
#   '公里',
#   '公路'],
#  ['海岸',
#   '中心',
#   '花蓮遊客',
#   '遊客',
#   '山坡',
#   '展示室',
#   '太平洋',
#   '沿著台',
#   '11',
#   '順著',
#   '風景區',
#   '內部',
#   '全區',
#   '資源',
#   '東部',
#   '沿線',
#   '旅遊據點',
#   '可容納',
#   '81',
#   '媒體',
#   '簡報',
#   '發遊',
#   '玩東',
#   '詢相關',
#   '旅遊',
#   '資訊',
#   '遼闊',
#   '絕佳',
#   '視野',
#   '遠眺',
#   '無際',
#   '這番',
#   '無敵',
#   '開滿',
#   '沿著',
#   '周邊',
#   '景觀步',
#   '縱覽',
#   '微風',
#   '中搖曳',
#   '波動',
#   '如畫',
#   '相當',
#   '由遊客',
#   '山脈',
#   '一覽',
#   '花蓮溪',
#   '交會',
#   '洄瀾',
#   '花蓮港',
#   '洄瀾港',
#   '花海',
#   '海景',
#   '水塘',
#   '北界',
#   '美景',
#   '景致',
#   '往北',
#   '百合',
#   '可到',
#   '陶醉',
#   '北端',
#   '一望',
#   '坐落',
#   '蜿蜒',
#   '人文',
#   '昔日',
#   '激起',
#   '面向',
#   '又名',
#   '不妨',
#   '般的',
#   '海洋',
#   '所在',
#   '享受',
#   '令人',
#   '道路',
#   '自然'],
#  ['遊客',
#   '泛舟',
#   '原住民',
#   '建築',
#   '中心',
#   '播放',
#   '影片',
#   '秀姑巒',
#   '花東',
#   '縱谷',
#   '大橋',
#   '姑巒',
#   '活動',
#   '起點',
#   '外觀',
#   '仿自',
#   '傳統',
#   '前廣場',
#   '相當',
#   '並設',
#   '有露',
#   '營區',
#   '季節',
#   '如織',
#   '瑞穗',
#   '雕像',
#   '造型',
#   '安全',
#   '巨大'],
#  ['海岸',
#   '部落',
#   '遊客',
#   '空間',
#   '交流',
#   '太平洋',
#   '2015',
#   '一號',
#   '奚卜蘭',
#   '開幕',
#   '團隊',
#   '進駐',
#   '邀請',
#   '台東',
#   '排灣族',
#   '傑出',
#   '設計師',
#   '謝聖華',
#   '發想',
#   '以溫',
#   '木造',
#   '進行',
#   '設計',
#   '更營造',
#   '書店',
#   '合經營',
#   '並作',
#   '工藝及',
#   '產物',
#   '展售',
#   '資訊',
#   '之處',
#   '未來',
#   '將陸續',
#   '活動',
#   '激盪',
#   '創意',
#   '作為',
#   '傳達屬',
#   '這不僅',
#   '志工',
#   '對遊客',
#   '路過',
#   '進來',
#   '面向世界',
#   '比斯',
#   '咖啡店',
#   '深耕',
#   '取用',
#   '休憩',
#   '中心',
#   '活化',
#   '坐坐',
#   '假期',
#   '隆重',
#   '分享',
#   '挖掘',
#   '元素',
#   '原本',
#   '原有',
#   '得以',
#   '青年',
#   '平台',
#   '故事',
#   '加入',
#   '朋友',
#   '推出',
#   '多年',
#   '功能',
#   '形式',
#   '提供',
#   '生活',
#   '不同',
#   '工作'],
#  ['觀光',
#   '村內',
#   '海岸',
#   '香茅油',
#   '早期',
#   '村位',
#   '花蓮縣',
#   '壽豐鄉',
#   '花蓮港',
#   '日治',
#   '時期',
#   '本來',
#   '屬水璉',
#   '1964',
#   '獨立',
#   '成村',
#   '東臨',
#   '狹長',
#   '涼爽',
#   '甚具',
#   '之開',
#   '發價值',
#   '觀擁',
#   '東部',
#   '國家',
#   '風景區',
#   '遠雄',
#   '公園',
#   '南寺',
#   '農耕',
#   '捕魚',
#   '為業',
#   '農產有',
#   '甘藷',
#   '魚產以',
#   '烏魚',
#   '苗及',
#   '現以',
#   '民宿',
#   '為主',
#   '文景',
#   '宜人',
#   '之名',
#   '花生',
#   '食用',
#   '夏季',
#   '太平洋',
#   '海洋'],
#  ['gt',
#   '農場',
#   '台灣',
#   '好行',
#   '資訊',
#   '無障礙',
#   '預約',
#   '多種',
#   '休閒',
#   '鮮奶',
#   '打水仗',
#   '的花海',
#   '步道',
#   '跑跳',
#   '渡假',
#   '大眾',
#   '運輸點',
#   '此連結',
#   '縱谷',
#   '花蓮線',
#   '時刻表',
#   '票價表',
#   '公車',
#   '歡迎',
#   '豐休',
#   '閒農場',
#   '遊樂',
#   '設施',
#   '生態',
#   '鳥園',
#   '鸚鵡園',
#   '並能夠',
#   '離拿著',
#   '而廣大',
#   '遼闊',
#   '青青草原',
#   '盡情',
#   '開放戲',
#   '水區',
#   '快樂地',
#   '度過',
#   '歡樂',
#   '時光',
#   '圍繞',
#   '豐農場',
#   '水美草豐',
#   '生氣',
#   '美的',
#   '生產出',
#   '優質',
#   '廣受',
#   '吃鮮',
#   '壯觀',
#   '歐式',
#   '花園',
#   '呈現',
#   '風情',
#   '二子山',
#   '溫泉',
#   '活動',
#   '沿著',
#   '騎著',
#   '電動車',
#   '鐵馬',
#   '...',
#   '奶瓶',
#   '乳牛',
#   '新光',
#   '冰淇淋',
#   '盎然',
#   '奶酪',
#   '小朋友',
#   '近距',
#   '漫步',
#   '夏日',
#   '一年四季',
#   '小牛',
#   '牧草',
#   '群山',
#   '孔雀',
#   '放牧',
#   '好吃',
#   '旅客',
#   '深受',
#   '小孩',
#   '享受',
#   '大人',
#   '一座',
#   '作出',
#   '如此',
#   '不同'],
#  ['鳳凰山莊',
#   '鳳林溪',
#   '鳳凰',
#   '規劃',
#   '賽斯村',
#   '露營區',
#   '設施',
#   '生態',
#   '旅遊',
#   '風景區',
#   '花東',
#   '心靈',
#   '瀑布',
#   '烤肉',
#   '自然',
#   '探索',
#   '潺潺流水',
#   '環境',
#   '庄鳳林鎮',
#   '西側',
#   '地區',
#   '場等',
#   '並也',
#   '購物',
#   '餐點',
#   '週邊',
#   '環抱',
#   '臨近',
#   '適合來',
#   '區的',
#   '水質',
#   '並擁',
#   '風貌',
#   '伴著',
#   '標示',
#   '往山邊',
#   '前進',
#   '看見秀麗',
#   '猶如',
#   '一條',
#   '銀絲',
#   '帶般',
#   '懸掛',
#   '空氣間',
#   '漫著',
#   '負離子',
#   '清淺',
#   '冰涼',
#   '透徹',
#   '極富',
#   '遊憩',
#   '勝地',
#   '鳳林鎮',
#   '將此區',
#   '帶來',
#   '一絲沁涼',
#   '縱谷',
#   '國家',
#   '便將',
#   '發展',
#   '的遊',
#   '憩區',
#   '建築',
#   '增設',
#   '相關',
#   '各種',
#   '活動',
#   '造訪',
#   '...',
#   '炎炎夏日',
#   '野趣',
#   '旅人',
#   '水源地',
#   '客家',
#   '甘甜',
#   '公所',
#   '潺潺',
#   '清幽',
#   '山壁',
#   '水潭',
#   '溪水',
#   '青山',
#   '享用',
#   '住宿',
#   '林地',
#   '清澈',
#   '一趟',
#   '每月',
#   '早年',
#   '原本',
#   '原有',
#   '原始',
#   '上游',
#   '及其',
#   '希望',
#   '成立',
#   '提供'],
#  ['鳳林',
#   '大阪',
#   '樓群',
#   '廣島式',
#   '排煙口',
#   '屋頂',
#   '國際',
#   '慢城',
#   '外觀',
#   '現和洋',
#   '風格',
#   '童話',
#   '般會',
#   '出現',
#   '建築',
#   '開始舉',
#   '辦鳳林',
#   '百鬼',
#   '觀光客',
#   '輕人',
#   '參加',
#   '專屬',
#   '創意',
#   '活動',
#   '樓建',
#   '日治',
#   '時期',
#   '當時',
#   '稱作',
#   '綠金',
#   '高經濟',
#   '價值',
#   '數量',
#   '指標',
#   '而鳳林',
#   '幾乎',
#   '既高且',
#   '排煙',
#   '因為',
#   '受風面',
#   '風時',
#   '樓則',
#   '剛好',
#   '緊貼',
#   '雖然',
#   '這座',
#   '慢城小鎮',
#   '校長',
#   '工廠',
#   '大榮',
#   '二村',
#   '欣賞',
#   '獨特',
#   '圖書館',
#   '當年',
#   '風華',
#   '...',
#   '容易',
#   '一村',
#   '生火',
#   '夜行',
#   '凸出',
#   '迷路',
#   '聚落',
#   '小吃',
#   '走入',
#   '走走',
#   '可分',
#   '富裕',
#   '七月',
#   '作物',
#   '不妨',
#   '不怕',
#   '特色',
#   '保留',
#   '完整',
#   '像是',
#   '相反',
#   '吸引',
#   '遇到',
#   '故事',
#   '效果',
#   '各地',
#   '程度',
#   '了解',
#   '文化',
#   '形式',
#   '之一',
#   '但是'],
#  ['張箭',
#   '鄧玉瑛',
#   '大橋',
#   '老師',
#   '鳳林鎮',
#   '山興里',
#   '位老師',
#   '這個',
#   '奉獻',
#   '箭瑛',
#   '犧牲',
#   '兩位',
#   '不幸',
#   '失足落水',
#   '一座',
#   '大榮里',
#   '之間',
#   '隔著',
#   '花蓮溪',
#   '以來',
#   '這兒僅',
#   '橋供',
#   '民國',
#   '66',
#   '因為',
#   '過境',
#   '竹橋',
#   '當時',
#   '服務',
#   '山興國',
#   '教務',
#   '國義與',
#   '林寶炫',
#   '上課',
#   '他們',
#   '仍手',
#   '牽著手',
#   '溺斃',
#   '殉職',
#   '當年',
#   '撼動',
#   '全國',
#   '極為',
#   '偏遠',
#   '地區',
#   '教師們',
#   '堅毅',
#   '時任',
#   '蔣經國',
#   '決定',
#   '撥款',
#   '興建',
#   '外聯絡',
#   '並將',
#   '此橋',
#   '以紀念',
#   '這兩位',
#   '攝成',
#   '電影',
#   '學子',
#   '偉大',
#   '家喻',
#   '戶曉',
#   '連帶',
#   '區的',
#   '紀念',
#   '...',
#   '精神',
#   '到校',
#   '感佩',
#   '此一',
#   '因公',
#   '消息',
#   '公所',
#   '枯水期',
#   '竹子',
#   '行政院',
#   '湍急',
#   '知名度',
#   '林地',
#   '渡河',
#   '途中',
#   '河水',
#   '通行',
#   '洪水',
#   '自古',
#   '命名',
#   '得知',
#   '夏天',
#   '水泥',
#   '打算',
#   '生命',
#   '故事',
#   '交通',
#   '改善',
#   '主任',
#   '即使',
#   '先生',
#   '大家',
#   '提高'],
#  ['泛舟',
#   '遊客',
#   '姑巒',
#   '瑞穗',
#   '溪畔',
#   '活動',
#   '秀姑巒',
#   '大橋',
#   '服務',
#   '河段',
#   '原住民',
#   '奇岩',
#   '花東',
#   '地區',
#   '莫屬',
#   '民國',
#   '70',
#   '為國內',
#   '首選',
#   '至長',
#   '虹橋',
#   '24',
#   '只見',
#   '紅艷艷',
#   '妝點',
#   '綺麗動',
#   '20',
#   '多處',
#   '難度',
#   '險灘',
#   '帶給',
#   '充滿',
#   '驚險',
#   '旅遊',
#   '經驗',
#   '而秀',
#   '峽谷',
#   '心頭',
#   '難以',
#   '忘懷',
#   '沿著',
#   '繞山',
#   '瑞港',
#   '數不清',
#   '廂型車',
#   '兩地',
#   '之間',
#   '接駁',
#   '載客',
#   '國家',
#   '風景區',
#   '南側',
#   '設立',
#   '這棟',
#   '傳統',
#   '建築',
#   '外觀',
#   '介紹秀',
#   '生態',
#   '資源',
#   '相關',
#   '資訊',
#   '還附設',
#   '有露',
#   '營區',
#   '活動季',
#   '節裡',
#   '...',
#   '整段',
#   '橡皮艇',
#   '刺激',
#   '中心',
#   '烙印',
#   '美景',
#   '穿梭',
#   '激流',
#   '播放',
#   '知名度',
#   '全程',
#   '久久',
#   '一艘',
#   '旺季',
#   '已成',
#   '而行',
#   '最具',
#   '水域',
#   '影片',
#   '河道',
#   '海岸',
#   '夏天',
#   '公里',
#   '公路',
#   '安全',
#   '自然',
#   '年代',
#   '提供',
#   '管理'],
#  ['溫泉',
#   '地區',
#   '瑞穗',
#   '紅葉',
#   '稱作',
#   '安通',
#   '花蓮',
#   '大溫泉區',
#   '略帶',
#   '金黃色',
#   '著生',
#   '男之泉',
#   '山區',
#   '水質',
#   '毫無',
#   '這兩種',
#   '歷史',
#   '環境',
#   '價位',
#   '風格',
#   '湯屋',
#   '民宿',
#   '泡湯',
#   '疲憊',
#   '獨有',
#   '溫度',
#   '圖片',
#   '來源',
#   '家慶攝',
#   '影師',
#   '1919',
#   '人開發',
#   '當時',
#   '當年',
#   '數一數',
#   '高級',
#   '旅館',
#   '溫泉屬',
#   '鹼性',
#   '鹽泉',
#   '鐵質',
#   '空氣',
#   '一層',
#   '稱為',
#   '湯花',
#   '溫泉花',
#   '金之湯',
#   '進出',
#   '必須',
#   '隔著',
#   '紅葉溪',
#   '相對望',
#   '之稱',
#   '豐富',
#   '日治',
#   '時代即',
#   '已聲',
#   '名遠播',
#   '...',
#   '滴翠',
#   '不竭',
#   '美名',
#   '氯化物',
#   '清幽',
#   '周遭',
#   '碳酸',
#   '提供',
#   '冬日',
#   '度假',
#   '清澈',
#   '故有',
#   '悠久',
#   '泉水',
#   '搭配',
#   '旅客',
#   '四季',
#   '水量',
#   '靠近',
#   '氧化',
#   '深深',
#   '味道',
#   '幸福',
#   '前往',
#   '一身',
#   '消除',
#   '水面',
#   '享受',
#   '吸引',
#   '遇到',
#   '不少',
#   '日本',
#   '不同',
#   '形成'],
#  ['北回',
#   '歸線',
#   '標誌',
#   '瑞穗',
#   '舞鶴',
#   '太陽',
#   '夏至',
#   '直射',
#   '天象',
#   '台地',
#   '造型',
#   '牌示',
#   '立竿',
#   '公園位',
#   '時必',
#   '景點',
#   '而公園',
#   '茶壺',
#   '裝置',
#   '藝術',
#   '廁所',
#   '公園',
#   '兩側',
#   '氣候',
#   '節氣',
#   '科學',
#   '相關',
#   '解說',
#   '還會',
#   '舉辦',
#   '235',
#   '活動',
#   '前來',
#   '探訪',
#   '紀錄',
#   '距離',
#   '最遠',
#   '北緯',
#   '23.5',
#   '時分',
#   '不見影',
#   '獨特',
#   '處設',
#   '分別',
#   '嘉義',
#   '花蓮',
#   '豐濱',
#   '設立',
#   '1933',
#   '火車',
#   '西側',
#   '爾後因',
#   '東線',
#   '鐵路拓',
#   '現址',
#   '不過',
#   '通過',
#   '號省',
#   '確實',
#   '地點',
#   '其實',
#   '...',
#   '日晷',
#   '人潮',
#   '休憩',
#   '周遭',
#   '夏日',
#   '正午',
#   '拍照',
#   '美食',
#   '北半球',
#   '旅客',
#   '赤道',
#   '水上',
#   '一共',
#   '表演',
#   '白色',
#   '地球',
#   '吸引',
#   '放在',
#   '位置',
#   '巨大',
#   '一天'],
#  ['溫泉',
#   '安通',
#   '浴場',
#   '溪畔',
#   '玉里',
#   '泡湯',
#   '公共',
#   '享受',
#   '來花東',
#   '縱谷',
#   '旅遊',
#   '欣賞',
#   '天際',
#   '疲勞',
#   '人間',
#   '歷史',
#   '花蓮',
#   '泉溫',
#   '66',
#   '不論',
#   '湯屋',
#   '民宿',
#   '中泡湯',
#   '挖池',
#   '獨有',
#   '溫暖',
#   '1904',
#   '採樟腦',
#   '發現',
#   '1930',
#   '此興建',
#   '並設',
#   '逐漸',
#   '發展',
#   '勝地',
#   '隨著',
#   '時間',
#   '過去',
#   '不過',
#   '溫泉業者',
#   '日治時',
#   '期興建',
#   '木造',
#   '建築',
#   '外觀',
#   '榻榻米',
#   '房間',
#   '相當',
#   '寫著',
#   '掛在',
#   '門楣',
#   '整棟',
#   '建築散',
#   '發出',
#   '幽靜怡',
#   '氣息',
#   '一條',
#   '所開闢',
#   '...',
#   '日式',
#   '油菜花',
#   '古色古香',
#   '旅社',
#   '日本',
#   '八景',
#   '延至',
#   '平房',
#   '冬日',
#   '露天',
#   '名列',
#   '招待所',
#   '泉水',
#   '入口',
#   '牌子',
#   '百年',
#   '警察',
#   '寒冷',
#   '清朝',
#   '改名',
#   '冬天',
#   '透明',
#   '一方',
#   '早年',
#   '消除',
#   '一大',
#   '保留',
#   '保存',
#   '一股',
#   '一名',
#   '至今',
#   '接近',
#   '良好',
#   '使得',
#   '之一'],
#  ['泥火山',
#   '瀑布',
#   '豆腐',
#   '眺望',
#   '憩區',
#   '噴出',
#   '瓦斯',
#   '手工',
#   '一道',
#   '山遊',
#   '景觀',
#   '聞名',
#   '到羅山遊',
#   '親自體驗',
#   '山大魚',
#   '沿著步',
#   '走則',
#   '可欣賞',
#   '奇觀',
#   '濱海',
#   '奧妙',
#   '山脈',
#   '斷層',
#   '高約',
#   '120',
#   '兩層',
#   '豐沛',
#   '氣勢',
#   '驚人',
#   '從遠方',
#   '見羅山',
#   '猶如',
#   '細細',
#   '懸掛',
#   '之間',
#   '花東',
#   '谷平原',
#   '機村',
#   '純樸',
#   '田園',
#   '風光',
#   '一覽',
#   '在羅山',
#   '當地',
#   '人稱',
#   '鹽坪',
#   '泥漿',
#   '同時',
#   '燒水',
#   '綿密',
#   '來羅山',
#   '必品',
#   '青翠',
#   '山有',
#   '可看',
#   '山壁',
#   '山村',
#   '口感',
#   '美食',
#   '大自然',
#   '水量',
#   '收集',
#   '燃料',
#   '海岸',
#   '特有',
#   '感受',
#   '上下',
#   '地形',
#   '含有',
#   '早就',
#   '做出',
#   '不但',
#   '居民',
#   '植物',
#   '形成',
#   '知道'],
#  ['落羽',
#   '欣賞',
#   '松林',
#   '這番',
#   '苗圃',
#   '美景',
#   '般的',
#   '網路',
#   '瘋傳',
#   '爆紅後的鈺展',
#   '絕美',
#   '不輸給',
#   '賞落',
#   '羽松',
#   '季節',
#   '金黃',
#   '落葉前',
#   '橘紅',
#   '總是',
#   '前來',
#   '朝聖',
#   '猶如北',
#   '國夢幻',
#   '風景',
#   '之際',
#   '鈺展',
#   '落羽松',
#   '從翠綠漸',
#   '漸轉',
#   '金黃燦爛',
#   '樹林',
#   '波光粼粼',
#   '水裡',
#   '優游',
#   '輝映',
#   '北國',
#   '風情',
#   '幾分',
#   '活潑',
#   '氣息',
#   '水畔',
#   '食錦',
#   '人度過',
#   '愜意',
#   '臨走',
#   '記得',
#   '隨手',
#   '繼續',
#   '留給',
#   '下午茶',
#   '整片',
#   '倒映在',
#   '人潮',
#   '喝杯',
#   '仙境',
#   '景致',
#   '秋冬',
#   '酷似',
#   '牧草',
#   '垃圾',
#   '其他人',
#   '增添',
#   '山水',
#   '一到',
#   '大片',
#   '大批',
#   '水中',
#   '冬季',
#   '相互',
#   '吸引',
#   '坐在',
#   '程度'],
#  ['落羽',
#   '山水',
#   '松林',
#   '歐洲',
#   '欣賞',
#   '湖畔',
#   '水中',
#   '享受',
#   '童趣',
#   '潺潺流水',
#   '自從',
#   '黑松汽水',
#   '這拍',
#   '攝廣告',
#   '而紅',
#   '絕美',
#   '風景',
#   '翠綠',
#   '隨著陽',
#   '光灑',
#   '現夢幻',
#   '變化',
#   '充滿',
#   '民宿',
#   '國外',
#   '遼闊',
#   '廣大',
#   '盡情',
#   '快樂',
#   '親子',
#   '時光',
#   '時刻',
#   '栽種',
#   '夢幻',
#   '尾花',
#   '紛紛',
#   '隨風',
#   '時節',
#   '小水壩',
#   '石磚步',
#   '聽著',
#   '由綠轉',
#   '變得繽紛',
#   '風景中',
#   '隨時',
#   '隨地',
#   '來此',
#   '看著',
#   '雲煙繚繞',
#   '山巒',
#   '輝映',
#   '艷陽',
#   '鍍上',
#   '一層',
#   '獨有',
#   '風情',
#   '貼心',
#   '進入',
#   '園區',
#   '入園費',
#   '水岸',
#   '多彩的',
#   '明信片',
#   '倒映在',
#   '高照',
#   '秋分',
#   '春分',
#   '一炮',
#   '青青',
#   '小朋友',
#   '置身',
#   '光影',
#   '正午',
#   '美景',
#   '宛如',
#   '金光',
#   '情不自禁',
#   '沉浸',
#   '紫色',
#   '柔和',
#   '花朵',
#   '草地',
#   '清晨',
#   '奔跑',
#   '城堡',
#   '收取',
#   '一旁',
#   '不妨',
#   '想要',
#   '般的',
#   '居住',
#   '森林',
#   '相互',
#   '提醒'],
#  ['風鈴木',
#   '興泉圳',
#   '景點',
#   '盛開',
#   '水圳',
#   '賞花',
#   '鄰近',
#   '學校',
#   '富源',
#   '停放',
#   '花朵',
#   '木花',
#   '蝴蝶谷',
#   '倘佯',
#   '潺潺流水',
#   '打卡',
#   '每當黃花',
#   '花季',
#   '臨時',
#   '紛紛',
#   '出現',
#   '追花',
#   '狂熱',
#   '而位',
#   '賞黃花',
#   '熱門',
#   '300',
#   '花風鈴',
#   '金黃色',
#   '遠方',
#   '襯托',
#   '水圳中',
#   '金黃燦爛',
#   '美的',
#   '油畫',
#   'IG',
#   'FB',
#   '興景點',
#   '興建',
#   '光緒',
#   '年間',
#   '歷史',
#   '台糖',
#   '並在',
#   '兩旁種',
#   '植風鈴木',
#   '花開',
#   '時節',
#   '遊客',
#   '因該',
#   '隨意',
#   '國中',
#   '並請',
#   '維持',
#   '順暢',
#   '農田',
#   '叢林',
#   '時須',
#   '建議',
#   '...',
#   '瑞穗',
#   '倒映在',
#   '防滑',
#   '田埂',
#   '滑倒',
#   '倒影',
#   '一不小心',
#   '周遭',
#   '漫漫',
#   '青山',
#   '交通工具',
#   '水田',
#   '接手',
#   '悠久',
#   '交界',
#   '百年',
#   '景色',
#   '一幅',
#   '美好',
#   '河道',
#   '清朝',
#   '一旁',
#   '相互',
#   '提醒',
#   '吸引',
#   '交通',
#   '各地',
#   '正是',
#   '近期',
#   '不少',
#   '一起',
#   '形成',
#   '重要',
#   '可能'],
#  ['拉索',
#   '生態',
#   '阿美族',
#   '秘境',
#   '埃湧泉',
#   '園區',
#   '石龍尾',
#   '神話',
#   '眼淚',
#   '藍色',
#   '號湧泉',
#   '村民',
#   '小花',
#   '清澈',
#   '乾旱',
#   '原始',
#   '好景不常',
#   '花蓮光',
#   '鮮為',
#   '人知',
#   '處湧泉',
#   '每一處',
#   '環境',
#   '維持',
#   '湛藍',
#   '調過',
#   '顏色',
#   '灣瀕臨',
#   '絕種',
#   '美的',
#   '景點',
#   '背後有',
#   '相傳神',
#   '守護',
#   '縱谷',
#   '獵人',
#   '所傷',
#   '埃村',
#   '接二連',
#   '爆發',
#   '神鳥',
#   '六滴',
#   '湧泉',
#   '豐饒',
#   '快樂的過',
#   '交織',
#   '選為',
#   '2016',
#   '隨著陽光',
#   '變化',
#   '灣版',
#   '見底',
#   '藻類邊',
#   '離欣賞',
#   '一場',
#   '...',
#   '幻化成',
#   '孕育出',
#   '九寨',
#   '奇幻',
#   '美名',
#   '近距',
#   '水生植物',
#   '划船',
#   '漂流',
#   '最美',
#   '感人',
#   '折射出',
#   '宛如',
#   '原生',
#   '瘟疫',
#   '解救',
#   '幸而',
#   '泉水',
#   '照料',
#   '世代',
#   '清理',
#   '落下',
#   '上帝',
#   '中共',
#   '像是',
#   '故事',
#   '居民',
#   '然而',
#   '自然',
#   '如此',
#   '生活',
#   '一直',
#   '不同'],
#  ['園區',
#   '車道',
#   '平地',
#   '大農',
#   '豐富',
#   '生態',
#   '賞楓',
#   '南環',
#   '山脈',
#   '大富',
#   '自行',
#   '森林',
#   '拍照',
#   '秋冬',
#   '春天',
#   '目光',
#   '杜英',
#   '賞花',
#   '賞螢',
#   '賞鳥',
#   '風采',
#   '內設',
#   '北環',
#   '邊騎',
#   '單車邊',
#   '芬多精',
#   '幸運',
#   '時還',
#   '環頸雉',
#   '出來',
#   '著蟲鳴',
#   '愜意',
#   '騎車',
#   '森林浴',
#   '包圍',
#   '視野',
#   '遼闊',
#   '欣賞',
#   '服務',
#   '前繽紛',
#   '而廣闊',
#   '上放著',
#   '極具',
#   '裝置',
#   '藝術',
#   '總是',
#   '熱門',
#   '草叢',
#   '開始',
#   '點點',
#   '螢光',
#   '紛飛',
#   '螢火蟲',
#   '數量',
#   '一條會',
#   '移動',
#   '銀河',
#   '移開',
#   '專心',
#   '導覽員',
#   '講解',
#   '之際',
#   '兩旁',
#   '楓香',
#   '青楓',
#   '逐漸',
#   '綠轉',
#   '變紅',
#   '許多人',
#   '前來',
#   '南還',
#   '單車',
#   '...',
#   '花海',
#   '巧思',
#   '多彩的',
#   '宛若',
#   '首座',
#   '一年四季',
#   '旅客',
#   '一到',
#   '一趟',
#   '夜晚',
#   '海岸',
#   '夏季',
#   '草原',
#   '抓住',
#   '不禁',
#   '享受',
#   '吸收',
#   '吸引',
#   '不得',
#   '中央',
#   '自然',
#   '中心',
#   '不同'],
#  ['鳳梨',
#   '富興',
#   '社區',
#   '軌道',
#   '坐著',
#   '小火',
#   '拍照',
#   '幸福',
#   '酸酸甜甜',
#   '土鳳梨產地',
#   '鳳梨產',
#   '季時',
#   '一顆',
#   '顆飽滿',
#   '輕軌',
#   '車經過',
#   '無際',
#   '鳳梨田',
#   '樹林',
#   '沿著',
#   '抵達',
#   '終點',
#   '農耕車',
#   '牽引',
#   '列車',
#   '當地',
#   '著富興',
#   '參觀',
#   '哪兒',
#   '號房',
#   '攝地',
#   '最後再',
#   '大口品',
#   '土鳳梨',
#   '金鑽鳳',
#   '產地',
#   '鮮採',
#   '1314',
#   '情侶',
#   '出遊',
#   '邊聽司',
#   '機介紹',
#   '生態',
#   '品種',
#   '520',
#   '便會',
#   '下來',
#   '美麗',
#   '幻湖',
#   '回憶',
#   '臨走',
#   '帶上',
#   '新鮮',
#   '農特產品',
#   '留念',
#   '回家吧',
#   '田中',
#   '多汁',
#   '甜美',
#   '搭上',
#   '造林',
#   '一望',
#   '走走',
#   '穿越',
#   '好吃',
#   '滋味',
#   '停下',
#   '全家',
#   '美好',
#   '不妨',
#   '爸爸',
#   '享受',
#   '森林',
#   '休息',
#   '故事',
#   '居民',
#   '留下',
#   '看看',
#   '最大',
#   '地方'],
#  ['東里車',
#   '東里',
#   '鐵馬',
#   '稻田',
#   '稻浪',
#   '綠色',
#   '田園',
#   '兩旁',
#   '自行',
#   '月台',
#   '美景',
#   '吸引',
#   '20',
#   '進出',
#   '山線',
#   '車站',
#   '一走進',
#   '無邊',
#   '無際',
#   '圍繞',
#   '壯觀',
#   '驚呼',
#   '遊客',
#   '前來',
#   '探訪',
#   '玉富',
#   '車道',
#   '起點',
#   '無垠',
#   '車友',
#   '必拜訪',
#   '站點',
#   '風貌',
#   '舊時',
#   '古情',
#   '花東',
#   '縱谷',
#   '邊騎',
#   '車邊',
#   '欣賞',
#   '當太陽',
#   '陽光灑',
#   '翠綠',
#   '隨風搖曳',
#   '眼簾',
#   '隨著',
#   '季節',
#   '變化',
#   '由綠轉',
#   '空氣間',
#   '漫著',
#   '稻香',
#   '騎著',
#   '單車',
#   '隨風搖',
#   '細細',
#   '靜謐',
#   '絕美風景',
#   '波波',
#   '秧苗',
#   '整片',
#   '阡陌',
#   '映入',
#   '不起眼',
#   '最美',
#   '景致',
#   '招牌',
#   '金色',
#   '田野',
#   '看似',
#   '升起',
#   '景色',
#   '北上',
#   '不已',
#   '前身',
#   '深深',
#   '小小的',
#   '感受',
#   '保留',
#   '令人',
#   '早期',
#   '每天',
#   '平均',
#   '不少',
#   '之一'],
#  ['車道',
#   '自行',
#   '玉富',
#   '板塊',
#   '橫跨',
#   '兩個',
#   '從玉里',
#   '富里',
#   '隨著',
#   '景觀',
#   '鐵道',
#   '歐亞大陸',
#   '菲律',
#   '賓海板',
#   '改建',
#   '亞洲',
#   '唯二',
#   '起點',
#   '東里',
#   '鐵馬',
#   '視野',
#   '遼闊',
#   '兩旁伴',
#   '無垠',
#   '姑巒',
#   '大橋',
#   '驚奇感',
#   '東線',
#   '約長',
#   '2007',
#   '改線',
#   '這條',
#   '舊鐵道',
#   '為玉富',
#   '獨一無二會長',
#   '平緩',
#   '適合',
#   '親子',
#   '出遊',
#   '騎鐵馬',
#   '地人',
#   '運動',
#   '人欣賞',
#   '變化',
#   '田園',
#   '線圖',
#   '景色宜人',
#   '阡陌',
#   '公分',
#   '坡度',
#   '有所不同',
#   '四季',
#   '前身',
#   '享受',
#   '公里',
#   '道路',
#   '唯一',
#   '每年',
#   '受到',
#   '地方',
#   '世界'],
#  ['gt',
#   '十八尊',
#   '花蓮',
#   '台灣',
#   '日式',
#   '石佛',
#   '縣定',
#   '三級',
#   '建設',
#   '好行',
#   '資訊',
#   '無障礙',
#   '預約',
#   '吉野',
#   '佛堂',
#   '吉安',
#   '寺院',
#   '移民',
#   '完整',
#   '保存',
#   '高野山',
#   '必看',
#   '川端',
#   '玩樂',
#   '欣賞',
#   '四國',
#   '傳統',
#   '建築',
#   '工法',
#   '寶形造',
#   '大眾',
#   '運輸點',
#   '此連結',
#   '縱谷',
#   '花蓮線',
#   '時刻表',
#   '票價表',
#   '公車',
#   '清淨',
#   '手水舍',
#   '質樸',
#   '莊嚴',
#   '肅穆',
#   '充滿',
#   '禪意',
#   '寧靜安詳',
#   '氛圍',
#   '日治時',
#   '期川端',
#   '滿二為',
#   '撫慰',
#   '現今',
#   '心靈',
#   '日治',
#   '時期',
#   '稱作',
#   '相當',
#   '大正',
#   '1917',
#   '滿二募',
#   '這座',
#   '布教',
#   '...',
#   '古意',
#   '修院',
#   '攻略',
#   '日本',
#   '口舌',
#   '真言',
#   '佛寺',
#   '走入',
#   '沉浸',
#   '身心',
#   '山水',
#   '六年',
#   '有名',
#   '不禁',
#   '一座',
#   '希望'],
#  ['認識',
#   '生態',
#   '吉利',
#   '秘境',
#   '戲水',
#   '清潭',
#   '拉氏',
#   '菊池',
#   '阿美族',
#   '山泉水',
#   '潺潺流水',
#   '環繞',
#   '山間',
#   '帶點',
#   '中國風',
#   '拱橋',
#   '環潭步',
#   '欣賞',
#   '喧囂',
#   '隱藏',
#   '花蓮',
#   '新興景點',
#   '擁有戲',
#   '浮島',
#   '設施',
#   '親子',
#   '日治',
#   '時期',
#   '儲木池',
#   '三層',
#   '蓄滿',
#   '清徹',
#   '雙色澤蟹',
#   '氏細',
#   '動物',
#   '棲地',
#   '聖地',
#   '隨著',
#   '業沒落',
#   '荒蕪',
#   '親水公園',
#   '橋上',
#   '涼亭',
#   '眺馬錫山',
#   '親朋',
#   '環境',
#   '必訪',
#   '景點',
#   '炎炎夏日',
#   '踏青',
#   '倒映在',
#   '一汪',
#   '祈雨',
#   '旅人',
#   '宛若',
#   '自然',
#   '伐木',
#   '清溪',
#   '清幽',
#   '家常',
#   '美景',
#   '美化',
#   '青山',
#   '原生',
#   '好友',
#   '源自',
#   '明月',
#   '都市',
#   '水道',
#   '山下',
#   '瀑布',
#   '整治',
#   '山中',
#   '原本',
#   '水中',
#   '水面',
#   '四周',
#   '上游',
#   '生物',
#   '留下',
#   '大小',
#   '近期',
#   '之一'],
#  ['牧場',
#   '姑巒',
#   '園區',
#   '瑞穗',
#   '牛奶',
#   '鮮奶',
#   '蒸牧場',
#   '溪畔',
#   '產地',
#   '當然',
#   '錯過',
#   '品嘗鮮',
#   '兩間',
#   '廣為',
#   '人知',
#   '位在秀',
#   '遊客',
#   '販售部',
#   '餐廳',
#   '可愛動物',
#   '喧囂',
#   '氣息',
#   '清淨',
#   '靜靜遠',
#   '眺秀',
#   '與秀',
#   '將自產',
#   '濃郁',
#   '各種',
#   '來杯',
#   '饅頭',
#   '香濃',
#   '最後別',
#   '餵食',
#   '動物',
#   '體驗',
#   '相鄰',
#   '香醇',
#   '冰淇淋',
#   '旅人',
#   '泛舟',
#   '迷你',
#   '清幽',
#   '漫步',
#   '作成',
#   '相伴',
#   '散步',
#   '山羊',
#   '一分',
#   '不容',
#   '滋味',
#   '冬天',
#   '夏天',
#   '享受',
#   '便是',
#   '一份',
#   '共有',
#   '自然',
#   '中心'],
#  ['gt',
#   '縱谷',
#   '魚潭',
#   '遊客',
#   '原住民',
#   '台灣',
#   '好行',
#   '資訊',
#   '無障礙',
#   '預約',
#   '花東',
#   'hellip',
#   '旅人',
#   '特色',
#   '中心',
#   '文解',
#   '大眾',
#   '運輸點',
#   '此連結',
#   '花蓮線',
#   '時刻表',
#   '票價表',
#   '公車',
#   '單車',
#   '伴手',
#   '禮販',
#   '賣部',
#   '詢解',
#   '服務',
#   '進遊客',
#   '一間',
#   '館舍',
#   '極具',
#   '內部',
#   '豐富',
#   '介紹',
#   '景觀',
#   '邁開',
#   '往內',
#   '兩旁',
#   '縱谷產業',
#   '說明',
#   '金針',
#   '無際',
#   '田園',
#   '風光',
#   '初鹿牧場',
#   '香純',
#   '鮮奶',
#   '盡導覽',
#   '魚潭遊',
#   '之際',
#   '產業',
#   '並規劃',
#   '重點',
#   '旅遊',
#   '貼心',
#   '台行',
#   '動輪',
#   '椅及',
#   '台電動',
#   '...',
#   '花海',
#   '走道',
#   '下午茶',
#   '休憩',
#   '喝杯',
#   '湖光山色',
#   '石山',
#   '美景',
#   '木雕',
#   '六十',
#   '一望',
#   '出租',
#   '展示',
#   '照片',
#   '步伐',
#   '迎接',
#   '模型',
#   '提醒',
#   '了解',
#   '文化',
#   '自然',
#   '提供',
#   '形成'],
#  ['鶴岡遊客',
#   '無障礙',
#   '瑞穗',
#   '柚子',
#   '中心',
#   '遊客',
#   '活動',
#   '輪椅',
#   '充電',
#   '11',
#   '文旦',
#   '緊靠',
#   '山脈',
#   '花東',
#   '縱谷',
#   '國家',
#   '風景',
#   '各樣',
#   '旅遊',
#   '親切',
#   '詢服務',
#   '遼闊',
#   '美麗',
#   '適合帶',
#   '寶貝',
#   '進行',
#   '休閒',
#   '帶點',
#   '中國風',
#   '涼亭',
#   '產地',
#   '以鶴岡',
#   '地區',
#   '樹開花',
#   '季節',
#   '這時',
#   '樹開',
#   '參加',
#   '舉辦',
#   '柚花健',
#   '柚花',
#   '中揮',
#   '貼心',
#   '台行動',
#   '內相關',
#   '服務',
#   '設施',
#   '服務鈴',
#   '行動',
#   '親子',
#   '公廁',
#   '汽機車',
#   '停車格',
#   '點字',
#   '飲水機',
#   '哺乳室',
#   '嬰兒',
#   '推車',
#   '手機',
#   '機車',
#   '空壓',
#   '機及',
#   '汽車',
#   '電瓶',
#   '視聽',
#   '...',
#   '出借',
#   '草皮',
#   '朵朵',
#   '旅人',
#   '休憩',
#   '坡道',
#   '正逢',
#   '手杖',
#   '一排排',
#   '白花',
#   '快感',
#   '中下旬',
#   '各式',
#   '清香',
#   '盲人',
#   '出名',
#   '本部',
#   '走路',
#   '小孩',
#   '前方',
#   '一旁',
#   '海岸',
#   '家中',
#   '享受',
#   '提醒',
#   '提供',
#   '管理',
#   '使用'],
#  ['無障礙',
#   '遊客',
#   '照護床',
#   '中心',
#   '泥火山',
#   '富里',
#   '山遊客',
#   '祈禱',
#   '服務',
#   '輪椅',
#   '老花眼',
#   '寄放',
#   '台九線',
#   '農會',
#   '展售',
#   '進入羅山遊',
#   '憩區',
#   '佔地',
#   '廣大',
#   '整潔',
#   '旅遊諮詢',
#   '哺集',
#   '乳室',
#   '手機',
#   '充電',
#   '地質',
#   '地景',
#   '欣賞',
#   'hellip',
#   '戶外',
#   '擺放',
#   '幾處',
#   '伴著',
#   '田園',
#   '攜帶',
#   '度過',
#   '悠閒',
#   '時光',
#   '繼續',
#   '拜訪',
#   '機村',
#   '奧秘',
#   '貼心',
#   '有行動',
#   '手搖車',
#   '內相關',
#   '設施',
#   '服務鈴',
#   '電梯',
#   '行動',
#   '親子',
#   '公廁',
#   '停車場',
#   '哺乳室',
#   '輪胎',
#   '充氣',
#   '汽車',
#   '緊急',
#   '電源',
#   '11',
#   '12',
#   '醫藥箱',
#   '13',
#   '雨傘',
#   '14',
#   '視聽室',
#   '...',
#   '出借',
#   '野餐',
#   '第一站',
#   '淋浴',
#   '坡道',
#   '一探',
#   '平板',
#   '桌椅',
#   '美食',
#   '青山',
#   '享用',
#   '借用',
#   '豆腐',
#   '行走',
#   '行李',
#   '美好',
#   '山中',
#   '穆斯林',
#   '影片',
#   '自行',
#   '前往',
#   '提醒',
#   '提供',
#   '使用'],
#  ['東華大學',
#   '草地',
#   '山脈',
#   '建築',
#   '風景',
#   '美景',
#   '搭配',
#   '步道',
#   '西依',
#   '東臨',
#   '連綿',
#   '不絕',
#   '諾大',
#   '校區',
#   '歐式',
#   '風格',
#   '美的',
#   '小華湖',
#   '華湖',
#   '東湖',
#   '以東湖',
#   '瀲灩',
#   '湖景',
#   '歐風',
#   '遠方',
#   '蒼綠',
#   '山巒',
#   '拍婚',
#   '紗照',
#   '經典',
#   '攝地',
#   '遼闊',
#   '嬉戲',
#   '帶點',
#   '花東',
#   '獨特',
#   '悠閒步',
#   '花蓮',
#   '校園',
#   '綠蔭',
#   '不時',
#   '莘莘學子',
#   '結伴',
#   '鳳凰花',
#   '季節',
#   '構成',
#   '交織',
#   '畫作',
#   '降臨',
#   '隱藏版',
#   '上欣賞',
#   '滿天',
#   '無垠',
#   '學生',
#   '專屬',
#   '獨特體驗',
#   '明信片',
#   '波光',
#   '旅人',
#   '宛若',
#   '湖光山色',
#   '浩瀚',
#   '青青',
#   '最富',
#   '三座',
#   '星空',
#   '最美',
#   '湖畔',
#   '遮蔽',
#   '景致',
#   '巍峨',
#   '盛名',
#   '新人',
#   '天堂',
#   '人文',
#   '追逐',
#   '而行',
#   '一幅',
#   '六月',
#   '小孩',
#   '上演',
#   '夜晚',
#   '海岸',
#   '正要',
#   '中央',
#   '自然',
#   '可是'],
#  ['瑞穗',
#   '鳳林',
#   '當年',
#   '旅人',
#   '便利商店',
#   '許多人',
#   '種植',
#   '生產地',
#   '販售',
#   '行經',
#   '紅葉',
#   '溫泉',
#   '對面',
#   '著一棟',
#   '一棟',
#   '層層',
#   '覆蓋',
#   '滄桑斑',
#   '紅磚',
#   '彩繪著',
#   '省思',
#   '新詩',
#   '畫作',
#   '遙想',
#   '日治',
#   '時期',
#   '稱作',
#   '綠金',
#   '具經濟',
#   '價值',
#   '人有',
#   '權能',
#   '當地',
#   '人種',
#   '大戰',
#   '結束',
#   '屋主',
#   '佃農',
#   '由仕紳',
#   '擔任',
#   '類似',
#   '現今',
#   '進行',
#   '僅存',
#   '14',
#   '因久',
#   '排煙',
#   '屋頂',
#   '建築',
#   '主體',
#   '呈現',
#   '頹傾',
#   '模樣',
#   '欣賞',
#   '第一印象',
#   '小巷子',
#   '黑瓦',
#   '失修',
#   '青苔',
#   '保正',
#   '聘用',
#   '漫步',
#   '小巷',
#   '深藏',
#   '路途',
#   '送往',
#   '木板',
#   '作物',
#   '二次',
#   '前往',
#   '小心',
#   '提到',
#   '完整',
#   '令人',
#   '分配',
#   '便是',
#   '早期',
#   '必要',
#   '如今',
#   '日本',
#   '非常',
#   '部分',
#   '世界',
#   '只有'],
#  ['阿美族',
#   '底棲性',
#   '魚類',
#   '生態',
#   '告生',
#   '態捕',
#   '魚法',
#   '魚蝦',
#   '巴拉',
#   '花蓮光',
#   '太鞍濕',
#   '湧泉',
#   '不絕',
#   '沼澤濕',
#   '豐富',
#   '鳥類',
#   '蛙類',
#   '多樣化',
#   '體驗',
#   '獨特',
#   '嘗到',
#   '現撈',
#   '吳郭魚',
#   '石頭',
#   '火鍋',
#   '一場',
#   '原民',
#   '太鞍是',
#   '傳統',
#   '區域',
#   '這裡長',
#   '樹豆',
#   'vataan',
#   '語樹豆',
#   'Palakaw',
#   '樹枝',
#   '三層',
#   '結構物',
#   '喜歡',
#   '小魚',
#   '棲息',
#   '時間',
#   '將九芎',
#   '樹枝間',
#   '抖入',
#   '魚網',
#   '而藏',
#   '底層',
#   '土虱',
#   '鰻魚',
#   '他們',
#   '堅守',
#   '原則',
#   '...',
#   '孕育出',
#   '不竭',
#   '攀附',
#   '一堂',
#   '水塘',
#   '竹筒',
#   '竹子',
#   '生活',
#   '美食',
#   '中空',
#   '展出',
#   '放入',
#   '三角',
#   '昔日',
#   '出入',
#   '智慧',
#   '特有',
#   '之意',
#   '感受',
#   '即可',
#   '水面',
#   '居住',
#   '天然',
#   '自由',
#   '放在',
#   '作出',
#   '自然',
#   '提出'],
#  ['火山',
#   '運動',
#   '遺跡',
#   '柱狀',
#   '節理',
#   '東部',
#   '狀柱',
#   '狀節理',
#   '地質',
#   '景觀',
#   '員貝島',
#   '地景',
#   '周圍',
#   '頸露頭',
#   '地質學',
#   '上極',
#   '參考',
#   '價值',
#   '百褶裙',
#   '峰峰',
#   '澎湖',
#   '媲美',
#   '奇特',
#   '地貌',
#   '海岸',
#   '完整',
#   '相同',
#   '之一',
#   '具有',
#   '研究',
#   '一般',
#   '包括',
#   '重要'],
#  ['最美',
#   '海洋',
#   '渡假',
#   '遠雄',
#   '公園',
#   '風景區',
#   '台灣',
#   '具國際',
#   '水準',
#   '休閒',
#   '旅遊及',
#   '王國',
#   '座落',
#   '第一座',
#   '海岸',
#   '最大'],
#  ['休憩',
#   '大石',
#   '崎海濱',
#   '區位',
#   '花蓮縣',
#   '豐濱',
#   '崎海灣',
#   '距離',
#   '花蓮市',
#   '40',
#   '周邊',
#   '環繞',
#   '點綴',
#   '高約',
#   '100',
#   '鼻山',
#   '並設',
#   '一條',
#   '鼻山步',
#   '910',
#   '石頭',
#   '階梯',
#   '構成',
#   '枕木',
#   '群山',
#   '南端',
#   '一座',
#   '公里',
#   '大部分',
#   '左右'],
#  ['水璉',
#   '阿美族',
#   '保護區',
#   '牛山',
#   '水蛭',
#   '自然',
#   '涵意',
#   '至磯崎之間',
#   '花東',
#   '五處',
#   '美麗',
#   '風景',
#   '紋理',
#   '地質學',
#   '優良',
#   '為漢族',
#   '社區',
#   '叢林',
#   '豐富',
#   '人稱',
#   '基偉',
#   '地岸',
#   'Ciwdiyan',
#   '盛產',
#   '漢人取',
#   '其諧',
#   '音稱',
#   '番薯',
#   '教材',
#   '茂密',
#   '灌木',
#   '水源',
#   '曲折',
#   '混合',
#   '居住',
#   '沿海',
#   '因而',
#   '很多',
#   '之一'],
#  ['景觀',
#   '海岸公路',
#   '蕃薯',
#   '18',
#   '號橋',
#   '最為',
#   '獨特',
#   '峽谷',
#   '觀賞',
#   '兩側',
#   '地質',
#   '堆積',
#   '比明顯',
#   '溪流',
#   '切割',
#   '海岸',
#   '地形',
#   '公路',
#   '作用',
#   '不同',
#   '形成'],
#  ['海岸公路',
#   '南寺位',
#   '傳慶',
#   '西元',
#   '1967',
#   '民國',
#   '56',
#   '時所',
#   '創建',
#   '東部',
#   '佛門',
#   '道場',
#   '藝術',
#   '山越',
#   '殿堂',
#   '修行',
#   '老和尚',
#   '佛教',
#   '著名',
#   '但是'],
#  ['秀姑巒',
#   '發源',
#   '姑巒',
#   '103',
#   '豐沛',
#   '灣東部',
#   '流經',
#   '切穿',
#   '山脈',
#   '峽谷',
#   '豐水期',
#   '遊客',
#   '體驗',
#   '活動',
#   '瑞穗',
#   '曲流',
#   '泛舟',
#   '快感',
#   '河川',
#   '五月',
#   '河水',
#   '河道',
#   '海岸',
#   '十月',
#   '全年',
#   '公里',
#   '每年',
#   '刺激',
#   '最大',
#   '形成'],
#  ['歸線',
#   '花蓮',
#   '北半球',
#   '溫帶',
#   '熱帶',
#   '環繞',
#   '個國家',
#   '灣就',
#   '標碑',
#   '分別位',
#   '嘉義的',
#   '舞鶴及',
#   '靜浦',
#   '21',
#   '22',
#   '太陽',
#   '夏至',
#   '三座',
#   '直射',
#   '正午',
#   '分界',
#   '水上',
#   '十六',
#   '每年'],
#  ['港口',
#   '原住民',
#   '洞位',
#   '花蓮縣',
#   '豐濱',
#   '南距',
#   '村約',
#   '鐘乳石',
#   '一塊',
#   '洞中',
#   '積水成',
#   '池大約',
#   '隨著',
#   '盈虧',
#   '漲落',
#   '稱作',
#   '石梯',
#   '洞穴',
#   '湖水',
#   '月亮',
#   '眼中',
#   '又名',
#   '部落',
#   '天然',
#   '公里',
#   '所以'],
#  ['絕美', '芭崎賣', '沿線', '上絕', '美的', '崎海灣', '鼻山山頭', '海景', '休憩', '眺望', '大石', '海岸'],
#  ['池南',
#   '哈崙',
#   '鐵道',
#   '林業',
#   '人們',
#   '森林',
#   '花蓮林業史',
#   '三大傳奇',
#   '起點',
#   '1930',
#   '開始',
#   '人規劃',
#   '國民',
#   '擴建',
#   '將近',
#   '50',
#   '花蓮',
#   '最輝煌',
#   '帝國',
#   '1989',
#   '禁伐',
#   '地處',
#   '從此',
#   '世隔絕',
#   '轉運站',
#   '轉型',
#   '遊樂區',
#   '緬懷',
#   '這段',
#   '時光',
#   '歷史',
#   '樟科為',
#   '交雜',
#   '著光',
#   '蠟樹',
#   '樹種',
#   '東部',
#   '烏頭',
#   '時常出',
#   '親近',
#   '選擇',
#   '桑科',
#   '工作站',
#   '裁撤',
#   '造林',
#   '深山',
#   '大自然',
#   '打造',
#   '特有',
#   '山地',
#   '公里',
#   '留下',
#   '直到',
#   '全面',
#   '日本',
#   '之一',
#   '政府'],
#  ['建築',
#   '美崙山',
#   '松園',
#   '別館',
#   '花蓮縣',
#   '僅存',
#   '日治',
#   '時期',
#   '一棟',
#   '軍事',
#   '制高點',
#   '優勢',
#   '視野',
#   '監控',
#   '軍艦',
#   '從前',
#   '南機場',
#   '飛機',
#   '滿天',
#   '松樹枝葉',
#   '這棟',
#   '顯得',
#   '隱密',
#   '起降',
#   '茂密',
#   '灰色',
#   '海面',
#   '太平洋',
#   '地理',
#   '完整',
#   '掌握',
#   '不但',
#   '良好'],
#  ['步道',
#   '倉步',
#   '花蓮市',
#   '原為',
#   '台泥',
#   '採礦',
#   '經花',
#   '蓮林區',
#   '規劃',
#   '適合民眾',
#   '健走',
#   '生態',
#   '路緩',
#   '植栽',
#   '豐富',
#   '綠意',
#   '隨著',
#   '山勢',
#   '逐漸',
#   '整個',
#   '奇萊',
#   '壯闊',
#   '休憩',
#   '盎然',
#   '俯瞰',
#   '整修',
#   '西郊',
#   '蜿蜒',
#   '草地',
#   '便利',
#   '太平洋',
#   '平原',
#   '道路',
#   '交通',
#   '管理'],
#  ['花蓮縣',
#   '鄉福興村',
#   '楓林步',
#   '種植',
#   '各種',
#   '杜鵑',
#   '相繼盛開',
#   '花丁子',
#   '櫻丹',
#   '火紅色',
#   '楓葉',
#   '詩畫',
#   '難以',
#   '忘懷',
#   '置身',
#   '吉安',
#   '漫步',
#   '桃花',
#   '有如',
#   '林中',
#   '花卉',
#   '梅花',
#   '秋季',
#   '一到',
#   '春天',
#   '相互',
#   '令人',
#   '公里',
#   '之中'],
#  ['流水',
#   '初英親',
#   '態公園',
#   '車道',
#   '內設',
#   '態池',
#   '小橋',
#   '水車',
#   '涼亭',
#   '兒童',
#   '遊憩',
#   '設施供',
#   '親子遊',
#   '周圍',
#   '樟樹',
#   '落羽',
#   '松樹',
#   '結合牧場',
#   '田園',
#   '綠地',
#   '英生態',
#   '親水公園',
#   '英山',
#   '有生',
#   '青青',
#   '潺潺',
#   '林立',
#   '水生',
#   '魅力',
#   '自行',
#   '所在'],
#  ['生態',
#   '原生植物',
#   '教科',
#   '知卡宣',
#   '舊名',
#   '1985',
#   '花蓮縣',
#   '規劃',
#   '知卡',
#   '宣成',
#   '遊憩',
#   '場所',
#   '園區',
#   '種類',
#   '豐富',
#   '珍貴',
#   '地原',
#   '綠色',
#   '廣場區',
#   '區域',
#   '保育',
#   '苗圃',
#   '吉安',
#   '水生植物',
#   '整修',
#   '假日',
#   '更能',
#   '八大',
#   '重要',
#   '至此',
#   '生物',
#   '植物',
#   '重新',
#   '自然',
#   '另外',
#   '政府'],
#  ['蓮花',
#   '千枝',
#   '園區',
#   '內育',
#   '60',
#   '多種',
#   '品種',
#   '採收數',
#   '2002',
#   '獲得',
#   '傑出',
#   '神農獎',
#   '花色',
#   '香味',
#   '十大',
#   '每日',
#   '青年',
#   '肯定',
#   '不同'],
#  ['金針',
#   '花海',
#   '景致',
#   '花田',
#   '齊名',
#   '赤科山',
#   '赤科三景',
#   '聞名',
#   '花季',
#   '開滿',
#   '那萬花',
#   '齊開',
#   '壯闊',
#   '來訪',
#   '遊客',
#   '驚呼',
#   '之餘',
#   '農民',
#   '採收',
#   '這番',
#   '含苞待放',
#   '整片',
#   '石山',
#   '穿梭',
#   '六十',
#   '山丘',
#   '人文'],
#  ['nan'],
#  ['瀑布',
#   '鐵份',
#   '水流',
#   '石公',
#   '山脈',
#   '西側',
#   '山頭',
#   '高約',
#   '26',
#   '銀絹',
#   '石階',
#   '更須',
#   '奮力',
#   '攔砂壩',
#   '當你',
#   '陣陣',
#   '不遠',
#   '一小',
#   '身影',
#   '出自',
#   '又名',
#   '海岸',
#   '想要',
#   '知道',
#   '主要'],
#  ['壽豐主', '校區', '花東', '縱谷', '北端', '坐落'],
#  ['建築',
#   '台灣少',
#   '諾亞',
#   '教會',
#   '綠色',
#   '覆蓋',
#   '神社',
#   '天主堂',
#   '神秘感',
#   '天主教堂',
#   '方舟',
#   '藤蔓',
#   '新城',
#   '增添',
#   '融合',
#   '特色',
#   '西方',
#   '日本'],
#  ['精舍',
#   '慈濟靜思',
#   '鄉康樂村',
#   '慈濟',
#   '一棟',
#   '灰瓦',
#   '白牆',
#   '素建築',
#   '佳民國',
#   '小旁',
#   '庭園',
#   '充滿',
#   '寧靜',
#   '日式',
#   '座落在',
#   '整座',
#   '功德',
#   '平和',
#   '新城',
#   '所在地',
#   '佛教',
#   '小型',
#   '著有',
#   '像是',
#   '等待'],
#  ['豐鄉',
#   '海岸',
#   '米棧',
#   '水璉',
#   '山脈',
#   '橫渡',
#   '將米',
#   '至壽',
#   '而米',
#   '棧村',
#   '中斷',
#   '挑夫',
#   '肩挑',
#   '古道',
#   '翻越',
#   '堆放',
#   '溪流',
#   '稻米',
#   '昔日',
#   '村民'],
#  ['鯉魚',
#   '潭北',
#   '魚潭位',
#   '壽豐',
#   '鄉池',
#   '山腳',
#   '因東',
#   '魚山',
#   '魚潭',
#   '分潭南',
#   '銅門',
#   '慕谷',
#   '慕魚',
#   '翡翠谷',
#   '南則',
#   '鄰近',
#   '池南',
#   '遊樂園區',
#   '景點',
#   '南村',
#   '命名',
#   '森林'],
#  ['鮑溪親',
#   '水園區',
#   '花蓮壽豐',
#   '導航',
#   '設定',
#   '鮑溪',
#   '花蓮市',
#   '丙線',
#   '魚潭',
#   '橋右轉',
#   '200',
#   '溪橋',
#   '轉白',
#   '鮑溪產業',
#   '抵達時',
#   '車輛',
#   '親近',
#   '下車',
#   '溪邊',
#   '水景',
#   '跋山涉水',
#   '重光',
#   '往下走',
#   '直行',
#   '溪水',
#   '停放',
#   '空地',
#   '道路',
#   '一片',
#   '看到',
#   '直接',
#   '需要'],
#  ['玉里',
#   '協天宮',
#   '灣花蓮縣',
#   '玉里鎮',
#   '廟宇',
#   '主祀',
#   '關聖',
#   '稱玉里',
#   '關帝',
#   '花東',
#   '三大廟',
#   '之稱',
#   '帝君'],
#  ['文史',
#   '熊本',
#   '參觀',
#   '館後照',
#   '豐田',
#   '景點',
#   '地圖',
#   '準備',
#   '尋找',
#   '僅存',
#   '廣島式',
#   '全台',
#   '唯一',
#   '一家'],
#  ['石山',
#   '六十',
#   '赤科山',
#   '太麻里',
#   '山為',
#   '花東',
#   '縱谷',
#   '三大金針',
#   '賞金針',
#   '富里',
#   '竹田村',
#   '東側',
#   '800',
#   '山脈',
#   '出現',
#   '無邊',
#   '無際',
#   '幾座',
#   '農舍',
#   '涼亭',
#   '金黃色',
#   '金針',
#   '花田間',
#   '樸質',
#   '田園',
#   '畫作',
#   '花海',
#   '景致',
#   '栽植',
#   '散落',
#   '田野',
#   '蜿蜒',
#   '山路',
#   '一幅',
#   '海岸',
#   '海拔',
#   '每年',
#   '形成'],
#  ['校長',
#   '工廠',
#   '閒置',
#   '空間',
#   '日據',
#   '時期',
#   '鳳林',
#   '支廳',
#   '官舍',
#   '鳳林國',
#   '張七郎',
#   '宿舍',
#   '第一'],
#  ['花蓮',
#   '機場',
#   '七星',
#   '詩意',
#   '名稱',
#   '花蓮師',
#   '範學院',
#   '一帶',
#   '因建設',
#   '填實',
#   '現在',
#   '指美崙',
#   '工業區',
#   '地區',
#   '有斷',
#   '海峽',
#   '美的',
#   '海灣',
#   '豐富',
#   '文景',
#   '弧形',
#   '零星',
#   '自然人',
#   '湖泊',
#   '富有',
#   '早年',
#   '以北',
#   '具有',
#   '需要',
#   '一般',
#   '形成'],
#  ['客家',
#   '器具',
#   '文物',
#   '展示',
#   '鳳林',
#   '公園',
#   '1993',
#   '灣東部',
#   '館藏',
#   '分為',
#   '兩層',
#   '一樓',
#   '花蓮',
#   '墾拓',
#   '歷史',
#   '運輸',
#   '二樓',
#   '農用',
#   '傳統',
#   '服飾',
#   '座落在',
#   '客家人',
#   '第一座',
#   '人文',
#   '耕作',
#   '移居',
#   '信仰',
#   '日常',
#   '常用',
#   '至今',
#   '成立'],
#  ['花蓮',
#   '社花',
#   '花蓮市',
#   '觀光',
#   '酒廠',
#   '舊址',
#   '創意',
#   '產業',
#   '園區',
#   '當時',
#   '日治',
#   '時期',
#   '為民營',
#   '宜蘭振拓',
#   '株式',
#   '蓮港',
#   '稻住',
#   '工場',
#   '為主',
#   '米酒',
#   '文化'],
#  ['溫泉',
#   '飯店',
#   '安通',
#   '花蓮',
#   '推薦',
#   '風情',
#   '建築',
#   '獨立',
#   '湯屋',
#   'SPA',
#   '湯女',
#   '湯及',
#   '餐廳',
#   '休閒',
#   '設備',
#   '花東',
#   '縱谷間',
#   '日式',
#   '座落',
#   '各式',
#   '青山',
#   '露天',
#   '保留',
#   '完整',
#   '包含'],
#  ['林田山',
#   '伐木',
#   '中山堂',
#   '過去',
#   '之稱',
#   '林田',
#   '森坂',
#   '日語',
#   '發音',
#   '摩里',
#   '薩卡',
#   '聞名',
#   '雖然',
#   '風華',
#   '但園區',
#   '中不僅',
#   '各種',
#   '傳統',
#   '物等',
#   '豐富',
#   '具規模',
#   '檜木',
#   '建築群',
#   '濃厚林業',
#   '歷史',
#   '來花東',
#   '縱谷',
#   '必拜訪',
#   '日式',
#   '文景',
#   '消防',
#   '留有',
#   '器具',
#   '山林',
#   '旅客',
#   '昔日',
#   '文物',
#   '完整',
#   '保存',
#   '上海'],
#  ['廣場',
#   '太平洋',
#   '花蓮漁港',
#   '賞鯨',
#   '碼頭',
#   '花蓮',
#   '漁市場',
#   '花蓮區',
#   '漁會',
#   '所環',
#   '灑落',
#   '座落',
#   '第一道',
#   '曙光',
#   '四周'],
#  ['步道',
#   '米步',
#   '八通',
#   '關越',
#   '東段',
#   '14',
#   '視野佳',
#   '沿著拉庫',
#   '拉庫',
#   '亞熱帶',
#   '寒帶',
#   '生態',
#   '體系',
#   '蘊育',
#   '豐富',
#   '多樣',
#   '資源',
#   '溪谷',
#   '瓦拉',
#   '坡度',
#   '特色',
#   '完整',
#   '公里',
#   '植物',
#   '一部分',
#   '具有'],
#  ['美崙山',
#   '步道',
#   '公園',
#   '花蓮市',
#   '有大',
#   '可遊憩',
#   '美麗',
#   '可遠眺',
#   '海景',
#   '草皮',
#   '蜿蜒',
#   '上山',
#   '呼吸',
#   '一座',
#   '城市'],
#  ['富東',
#   '石門',
#   '削出',
#   '一條',
#   '小峽谷',
#   '兩岸',
#   '台灣',
#   '山層',
#   '揭露出',
#   '溪谷',
#   '洗刷',
#   '溪水',
#   '八百',
#   '陡峭',
#   '古老',
#   '地形',
#   '公路'],
#  ['公園',
#   '花蓮市',
#   '區東',
#   '北濱',
#   '花蓮港',
#   '美崙溪',
#   '之間',
#   '南可通',
#   '南濱',
#   '北則',
#   '地廣闊',
#   '沿濱海',
#   '毫無',
#   '呈現',
#   '北角',
#   '七星',
#   '遮掩',
#   '前行',
#   '大道',
#   '太平洋',
#   '前往',
#   '位置',
#   '清楚'],
#  ['遊憩',
#   '服務',
#   '卓溪',
#   '天遊',
#   '憩區位',
#   '花蓮縣',
#   '鄉古風',
#   '村崙天',
#   '區內',
#   '有餐',
#   '停車場',
#   '相關',
#   '設施',
#   '區裡',
#   '圓形',
#   '劇場',
#   '建築外',
#   '觀都展',
#   '現出',
#   '濃濃',
#   '布農族',
#   '中心',
#   '露天',
#   '住宿',
#   '部落',
#   '特色'],
#  ['2002',
#   '過高',
#   '花蓮糖',
#   '停產並',
#   '關閉',
#   '最後結合',
#   '觀光',
#   '轉型並',
#   '花蓮觀',
#   '光糖廠',
#   '園區',
#   '規劃',
#   '木構',
#   '造建築群',
#   '冰品',
#   '販賣部',
#   '特產展售',
#   '餐廳',
#   '日式',
#   '客服',
#   '不得已',
#   '商店',
#   '更名',
#   '成本',
#   '中心'],
#  ['生態',
#   '花蓮光',
#   '太鞍濕',
#   '湧泉',
#   '不絕',
#   '沼澤濕',
#   '豐富',
#   '鳥類',
#   '蛙類',
#   '底棲性',
#   '魚類',
#   '多樣化',
#   '體驗',
#   '獨特',
#   '告生',
#   '態捕',
#   '魚法',
#   '嘗到',
#   '現撈',
#   '魚蝦',
#   '吳郭魚',
#   '石頭',
#   '火鍋',
#   '一場',
#   '原民',
#   '孕育出',
#   '巴拉',
#   '一堂',
#   '美食',
#   '特有',
#   '天然',
#   '自然'],
#  ['阿美族',
#   '部落',
#   '螃蟹',
#   '語有',
#   '中處',
#   '生動',
#   '圖騰',
#   '傳統',
#   '刀槍',
#   '酒皿',
#   '家屋',
#   '木雕',
#   '文物',
#   '保留',
#   '意思'],
#  ['步道',
#   '入口',
#   '蘇花',
#   '國家',
#   '公園',
#   '仁步',
#   '處現',
#   '因風災',
#   '損壞',
#   '165',
#   '出步',
#   '走過',
#   '小樹林',
#   '仁海灘',
#   '界碑',
#   '一小',
#   '公路',
#   '左右'],
#  ['公路',
#   '嶺位',
#   '山脈主',
#   '鞍部',
#   '合歡',
#   '畢祿山',
#   '之間',
#   '565',
#   '橫貫',
#   '中點',
#   '花蓮',
#   '縣市',
#   '合歡山',
#   '梨山',
#   '一條',
#   '太魯閣',
#   '因處',
#   '農家',
#   '販售',
#   '白雲間',
#   '透著',
#   '鄉野',
#   '趕集',
#   '熱絡',
#   '淳厚',
#   '南投',
#   '三叉',
#   '一往',
#   '蔬果',
#   '集散',
#   '青山',
#   '大禹',
#   '路旁',
#   '交界',
#   '多有',
#   '聚集',
#   '高山',
#   '之地',
#   '前往',
#   '海拔',
#   '中部',
#   '早期',
#   '中央'],
#  ['關原',
#   '2374',
#   '氣候',
#   '條件',
#   '立霧',
#   '常匯',
#   '雲海',
#   '充滿',
#   '飄邈',
#   '朦朧',
#   '美麗',
#   '溪水',
#   '集成',
#   '海拔',
#   '高度'],
#  ['景點',
#   '簡介新白',
#   '楊為',
#   '合歡',
#   '1644',
#   '太魯閣',
#   '國家',
#   '公園',
#   '停車場',
#   '公廁',
#   '遊客',
#   '休憩',
#   '山系',
#   '海拔',
#   '提供'],
#  ['秀林',
#   '太魯閣',
#   '國家',
#   '公園',
#   '開放',
#   '實驗',
#   '學校',
#   '原為',
#   '鄉富',
#   '世國',
#   '小之西',
#   '花蓮縣',
#   '實施',
#   '學舍制',
#   '國民小學',
#   '文化背景',
#   '分校',
#   '前瞻性',
#   '地理位置',
#   '多元',
#   '一所',
#   '森林',
#   '唯一',
#   '特殊',
#   '教育'],
#  ['柴魚',
#   '七星',
#   '館位',
#   '花蓮',
#   '風景區',
#   '原為',
#   '廢棄',
#   '經空間',
#   '轉變',
#   '生態',
#   '主題',
#   '博物',
#   '人文',
#   '已久',
#   '改造',
#   '特色',
#   '加工',
#   '具有'],
#  ['石雕',
#   '花蓮縣',
#   '藝術',
#   '台灣',
#   '博物',
#   '得天',
#   '獨厚地',
#   '豐富',
#   '礦石',
#   '資源',
#   '並成',
#   '國內',
#   '大本營',
#   '全國',
#   '作為',
#   '主題',
#   '發展史',
#   '編寫',
#   '一頁',
#   '同時',
#   '發展',
#   '產業',
#   '實踐',
#   '新的篇章',
#   '石材',
#   '首座',
#   '最佳',
#   '地形',
#   '特色',
#   '天然',
#   '不但',
#   '文化',
#   '地方'],
#  ['石藝',
#   '藝品',
#   '石材',
#   '大街',
#   '集結',
#   '各類',
#   '灣玉',
#   '展售',
#   '整體',
#   '景觀',
#   '規劃',
#   '遊客',
#   '細細',
#   '琳瑯',
#   '品味',
#   '玉石',
#   '精美',
#   '水晶',
#   '海岸',
#   '心情',
#   '配合',
#   '共同',
#   '目的'],
#  ['公園',
#   '花蓮南濱',
#   '20',
#   '公頃',
#   '920',
#   '濱臨',
#   '園內',
#   '小橋',
#   '樓閣',
#   '還立',
#   '劃分',
#   '露營區',
#   '騎馬俱樂部',
#   '兒童',
#   '遊樂場',
#   '亭榭',
#   '海洋生物',
#   '塑像',
#   '椰子',
#   '草地',
#   '流水',
#   '海岸',
#   '太平洋'],
#  ['慈濟',
#   '園區',
#   '花蓮市',
#   '醫學',
#   '靜思堂',
#   '靜思',
#   '竹軒',
#   '大學園區',
#   '現出',
#   '慈濟證',
#   '嚴上',
#   '醫療',
#   '志業',
#   '文化',
#   '致力',
#   '坐落',
#   '凝聚',
#   '慈善',
#   '四大',
#   '包含',
#   '教育',
#   '精神',
#   '中央',
#   '中心'],
#  ['古道',
#   '錐麓',
#   '合歡',
#   '越嶺',
#   '原為',
#   '日治',
#   '時期',
#   '開鑿',
#   '開築',
#   '橫貫',
#   '700',
#   '800',
#   '原貌',
#   '路段',
#   '一部',
#   '保存',
#   '海拔',
#   '中部',
#   '道路',
#   '公路',
#   '如今',
#   '左右'],
#  ['太魯閣',
#   '公里',
#   '布洛灣遊',
#   '憩區位',
#   '中橫',
#   '布洛灣',
#   '東距',
#   '天祥約',
#   '國家',
#   '公園',
#   '處費時',
#   '規劃',
#   '闢建',
#   '為主題',
#   '西到',
#   '燕子',
#   '台地',
#   '文物',
#   '展示',
#   '保存',
#   '山地',
#   '管理'],
#  ['太魯閣',
#   '綠水步',
#   '綠水',
#   '優恩',
#   '現今',
#   '地質',
#   '相繼作',
#   '花蓮縣',
#   '風景區',
#   '國家',
#   '公園',
#   '公室',
#   '管理所',
#   '族人',
#   '警察',
#   '展示',
#   '早年',
#   '部落',
#   '地形',
#   '管理',
#   '政府'],
#  ['花池',
#   '太魯閣',
#   '國家',
#   '公園',
#   '區域',
#   '1180',
#   '日治',
#   '時期',
#   '天潭',
#   '因池',
#   '開滿',
#   '為蓮',
#   '海拔高度',
#   '布袋',
#   '族人',
#   '更名',
#   '湖泊',
#   '高山',
#   '天然',
#   '唯一'],
#  ['梅園',
#   '竹村步',
#   '12.4',
#   'Km',
#   '竹村',
#   '路徑',
#   '沿大沙溪',
#   '開鑿',
#   '多吊橋',
#   '可欣賞',
#   '景觀',
#   '溪流',
#   '石壁',
#   '交通要道',
#   '左岸'],
#  ['三棧',
#   '風景區',
#   '小太魯閣',
#   '之稱',
#   '位處',
#   '太魯閣',
#   '國家',
#   '公園',
#   '範圍',
#   '以三棧',
#   '而後在',
#   '會合',
#   '北溪',
#   '南溪',
#   '布拉',
#   '出海',
#   '主流',
#   '太平洋',
#   '注入'],
#  ['清水溪',
#   '木瓜溪',
#   '秀林',
#   '慕谷',
#   '慕魚位',
#   '花蓮縣',
#   '鄉銅門村',
#   '面積',
#   '涵蓋',
#   '溪長',
#   '40',
#   '組成',
#   '呈翠綠色',
#   '此處',
#   '翡翠谷',
#   '小天祥',
#   '美稱',
#   '溪水',
#   '美景',
#   '源自',
#   '故有',
#   '山林',
#   '河床',
#   '大理石',
#   '高山',
#   '支流',
#   '原始',
#   '特色',
#   '公里',
#   '及其'],
#  ['地下水',
#   '水簾洞',
#   '進行',
#   '立霧',
#   '發電計',
#   '畫時',
#   '修築此',
#   '挖破',
#   '循著',
#   '間斷',
#   '裂隙',
#   '不慎',
#   '水力',
#   '成因',
#   '隧道',
#   '岩石',
#   '流出',
#   '不曾',
#   '主要'],
#  ['鐵道',
#   '園區',
#   '台灣',
#   '僅存',
#   '軌鐵道',
#   '遺址',
#   '其景觀',
#   '火車',
#   '幹線',
#   '系統',
#   '位處',
#   '花蓮',
#   '截然不同',
#   '市中心',
#   '完整',
#   '西部',
#   '文化'],
#  ['舊鐵道',
#   '市區',
#   '花蓮市',
#   '花東',
#   '鐵路',
#   '過花蓮',
#   '海邊',
#   '火車',
#   '總站',
#   '鐵道',
#   '1.8',
#   '1979',
#   '年北',
#   '車後',
#   '轉移',
#   '逐漸',
#   '雜亂',
#   '路通',
#   '昔日',
#   '重心',
#   '原有',
#   '失去',
#   '公里',
#   '交通',
#   '功能'],
#  ['南安',
#   '瀑布',
#   '玉里鎮',
#   '沿著台',
#   '30',
#   '50',
#   '垂掛',
#   '氣勢',
#   '米步',
#   '必經過',
#   '景點',
#   '瓦拉',
#   '山壁',
#   '往西',
#   '路旁',
#   '公路'],
#  ['國家',
#   '公園',
#   '處位',
#   '縣水里',
#   '水溪',
#   '水里溪',
#   '匯流處',
#   '絕佳',
#   '觀景',
#   '環境',
#   '可遠眺',
#   '山巒峻',
#   '谷及',
#   '南投',
#   '晨曦',
#   '晚霞',
#   '玉山',
#   '台地',
#   '管理'],
#  ['兩潭',
#   '車道',
#   '公園',
#   '自行',
#   '瀕臨',
#   '因為',
#   '連接',
#   '魚潭及',
#   '數人會',
#   '南濱',
#   '起點',
#   '行經',
#   '北濱',
#   '花蓮鳥',
#   '石公園',
#   '花蓮港',
#   '七星',
#   '曙光',
#   '太平洋',
#   '大多'],
#  ['海岸',
#   '沿著台',
#   '11',
#   '順著',
#   '風景區',
#   '花蓮遊客',
#   '遊客',
#   '內部',
#   '全區',
#   '資源',
#   '東部',
#   '沿線',
#   '旅遊據點',
#   '中心',
#   '北端',
#   '坐落',
#   '蜿蜒',
#   '人文',
#   '山坡',
#   '道路',
#   '自然'],
#  ['富源',
#   '龍吟',
#   '吊橋',
#   '四通',
#   '國家',
#   '遊樂區',
#   '溪所貫',
#   '八達',
#   '環山步',
#   '處為',
#   '集賞',
#   '賞蝶',
#   '森林浴',
#   '湯為',
#   '一體',
#   '遊客',
#   '多樣化',
#   '遊憩',
#   '體驗',
#   '清幽',
#   '最深',
#   '瀑布',
#   '森林',
#   '提供'],
#  ['信士',
#   '漁民',
#   '宜蘭',
#   '縣頭',
#   '城鎮',
#   '草嶺',
#   '慶雲宮',
#   '迎回',
#   '建廟',
#   '土角築壇',
#   '1952',
#   '游貽鐘',
#   '當時',
#   '阿樹',
#   '發動',
#   '信眾',
#   '1953',
#   '天公',
#   '嘉里',
#   '主神',
#   '玉皇',
#   '茅草',
#   '落成',
#   '供奉',
#   '保安',
#   '竣工',
#   '上帝',
#   '重建',
#   '初期',
#   '直到',
#   '年底',
#   '地方'],
#  ['鶴岡紅',
#   '瑞穗',
#   '鶴岡村位',
#   '花蓮縣',
#   '鄉東側',
#   '隔著',
#   '市街',
#   '遙遙',
#   '相對',
#   '民國',
#   '50',
#   '這兒',
#   '揚名',
#   '因市場',
#   '條件',
#   '轉變',
#   '銷售',
#   '蕭條',
#   '富源',
#   '山坡',
#   '日益',
#   '海外',
#   '地上',
#   '年代'],
#  ['虎頭山',
#   '打馬',
#   '山脈',
#   '脊嶺丹',
#   '支脈',
#   '因山頂',
#   '傲踞',
#   '山頭',
#   '故俗',
#   '伏虎',
#   '巨石',
#   '有如',
#   '中段',
#   '大山',
#   '燕山',
#   '原名',
#   '延伸',
#   '突出',
#   '中央'],
#  ['溫泉',
#   '稱外',
#   '西元',
#   '1919',
#   '已開',
#   '發為',
#   '浴場',
#   '瑞穗',
#   '日人',
#   '滴翠',
#   '招待所',
#   '警察',
#   '公共',
#   '建有'],
#  ['紅葉',
#   '溫泉',
#   '兩處',
#   '東縣',
#   '紅葉溪',
#   '流經',
#   '台東',
#   '縱谷',
#   '台灣',
#   '最長',
#   '紅葉谷',
#   '這處',
#   '泉河',
#   '延平',
#   '蜿蜒',
#   '平原',
#   '形成'],
#  ['跑跳',
#   '以鮮奶',
#   '暢銷',
#   '牧場',
#   '著餐',
#   '飲部',
#   '設施',
#   '產地',
#   '現榨',
#   '現煮',
#   '鮮奶',
#   '鴕鳥',
#   '悠閒',
#   '親手',
#   '遼闊',
#   '園區',
#   '盡情',
#   '適合',
#   '親子',
#   '同遊',
#   '景點',
#   '瑞穗',
#   '乳牛',
#   '小朋友',
#   '漫步',
#   '玩耍',
#   '牧草',
#   '露天',
#   '草地',
#   '成群',
#   '咖啡',
#   '各地',
#   '孩子',
#   '一起'],
#  ['活動',
#   '佛祖',
#   '浴佛',
#   '祠釋',
#   '迦牟尼',
#   '媽祖',
#   '關聖',
#   '最為',
#   '當地',
#   '樂道',
#   '內還',
#   '著一個',
#   '久遠且',
#   '裝過',
#   '視為',
#   '鎮寺',
#   '之寶的',
#   '竹籠',
#   '聖誕日',
#   '青蓮寺',
#   '儀式',
#   '春節',
#   '期間',
#   '舉辦',
#   '大規模',
#   '誦經',
#   '夜尋',
#   '津津',
#   '帝君',
#   '城隍',
#   '祈福',
#   '民俗',
#   '神像',
#   '供奉',
#   '居民',
#   '大型',
#   '每年',
#   '年代'],
#  ['泛舟',
#   '奇岩',
#   '大橋',
#   '至長',
#   '虹橋',
#   '24',
#   '只見',
#   '紅艷艷',
#   '妝點',
#   '綺麗動',
#   '20',
#   '多處',
#   '難度',
#   '險灘',
#   '帶給',
#   '遊客',
#   '充滿',
#   '驚險',
#   '旅遊',
#   '經驗',
#   '而秀',
#   '姑巒',
#   '峽谷',
#   '心頭',
#   '難以',
#   '忘懷',
#   '瑞穗',
#   '整段',
#   '橡皮艇',
#   '烙印',
#   '美景',
#   '激流',
#   '河段',
#   '全程',
#   '久久',
#   '一艘',
#   '旺季',
#   '河道',
#   '夏天',
#   '公里',
#   '刺激',
#   '自然'],
#  ['特展',
#   '本館',
#   '文物',
#   '部落',
#   '原住民',
#   '91',
#   '年興建',
#   '96',
#   '13',
#   '開館',
#   '為二層',
#   '建築',
#   '一樓',
#   '庫房',
#   '電腦',
#   '閱讀',
#   '二樓',
#   '為陽',
#   '台區',
#   '規劃',
#   '餐廳',
#   '明確',
#   '全鄉',
#   '性文物',
#   '團體',
#   '參與',
#   '權利',
#   '辦理',
#   '研習',
#   '結合秀',
#   '姑巒',
#   '生態',
#   '體驗',
#   '以豐富',
#   '內涵',
#   '公室',
#   '各式',
#   '保有',
#   '教室',
#   '同等',
#   '展示',
#   '各方',
#   '定位',
#   '原有',
#   '特色',
#   '努力',
#   '多年',
#   '逐步',
#   '人士'],
#  ['舞鶴',
#   '巨石',
#   '石柱',
#   '遺址',
#   '文化',
#   '阿美族',
#   '英國',
#   '活島',
#   '摩艾',
#   '都屬',
#   '重達',
#   '幾公噸',
#   'Satokoay',
#   '掃叭',
#   '歷史',
#   '遺跡',
#   '當地',
#   '奇萊雅族',
#   '謎團',
#   '這兩根',
#   '高聳',
#   '充滿',
#   '空間',
#   '瑞穗',
#   '至今已有',
#   '千多年',
#   '史前',
#   '矗立',
#   '想像',
#   '台地',
#   '神秘',
#   '地面'],
#  ['北回',
#   '歸線',
#   '標誌',
#   '舞鶴',
#   '台地',
#   '公園位',
#   '時必',
#   '景點',
#   '瑞穗',
#   '日晷',
#   '拍照',
#   '旅客',
#   '造型',
#   '白色'],
#  ['生長',
#   '100',
#   '300',
#   '舞鶴',
#   '高聳',
#   '山脈',
#   '隨風',
#   '拂來秀',
#   '姑巒',
#   '紅葉溪',
#   '濕潤',
#   '水氣',
#   '氣候',
#   '適合',
#   '茶樹',
#   '天鶴茶',
#   '產地',
#   '小葉',
#   '綠蟬',
#   '地點',
#   '依傍',
#   '宜人',
#   '台地',
#   '海拔',
#   '中央'],
#  ['山脈',
#   '三角',
#   '海岸',
#   '步道',
#   '公里',
#   '月眉',
#   '似眉',
#   '因得',
#   '西隔',
#   '花蓮溪',
#   '東眺',
#   '點的',
#   '國家步',
#   '二處',
#   '總長',
#   '4.8',
#   '點位',
#   '中間',
#   '2.4',
#   '眉山',
#   '山岳',
#   '其名',
#   '形如',
#   '第一座',
#   '相望',
#   '一等',
#   '北起',
#   '入口',
#   '村庄',
#   '部落',
#   '太平洋',
#   '南北',
#   '唯一',
#   '中央'],
#  ['日治',
#   '時代',
#   '豐田',
#   '所在地',
#   '移民',
#   '碧蓮寺位',
#   '豐裡村',
#   '村中里',
#   '豐坪村',
#   '大平',
#   '日治時',
#   '代森本',
#   '聚落',
#   '交界',
#   '南方',
#   '接近',
#   '地方'],
#  ['鯉魚',
#   '忠勇',
#   '高尾',
#   '內湖',
#   '人氣',
#   '極佳',
#   '郊山',
#   '山及',
#   '圓覺',
#   '湖三尖',
#   '山位',
#   '山東',
#   '兩山連',
#   '有顆',
#   '山勢',
#   '呈頭',
#   '尖山',
#   '四等',
#   '三座',
#   '整座',
#   '酷似',
#   '三角',
#   '得名',
#   '南方',
#   '包括'],
#  ['竹林',
#   '步道',
#   '富興步',
#   '320',
#   '屬低',
#   '山區',
#   '穿過',
#   '樹林',
#   '以桂',
#   '面積',
#   '廊道',
#   '海拔高度',
#   '相思',
#   '登上',
#   '海拔',
#   '走出',
#   '最高',
#   '代表',
#   '最大'],
#  ['步道',
#   '蝙蝠洞',
#   '區內',
#   '全台灣',
#   '樟樹林',
#   '園區',
#   '規劃',
#   '條步',
#   '環溪',
#   '生態',
#   '芬多',
#   '精步',
#   '相連',
#   '網絡',
#   '吊橋',
#   '景觀',
#   '巨石',
#   '瀑布',
#   '彼此',
#   '最大',
#   '形成'],
#  ['海岸',
#   '道路',
#   '山脈',
#   '連通',
#   '東部',
#   '及花東',
#   '縱谷',
#   '日治',
#   '時期',
#   '傳教',
#   '挑貨',
#   '通婚',
#   '跨越',
#   '清朝',
#   '第一',
#   '重要'],
#  ['八通',
#   '卓溪',
#   '吊索',
#   '鹿鳴',
#   '吊橋',
#   '段步',
#   '花蓮縣',
#   '日治',
#   '時期',
#   '關越',
#   '闊葉',
#   '緩坡',
#   '可觀',
#   '賞亞',
#   '熱帶',
#   '欣賞',
#   '庫拉庫',
#   '壯闊',
#   '之美',
#   '體驗',
#   '古道',
#   '林中',
#   '全程',
#   '一部',
#   '植物',
#   '特殊'],
#  ['深層',
#   '園區',
#   '海水',
#   '步道',
#   '台肥',
#   '花蓮',
#   '全台灣',
#   '穩定',
#   '供應',
#   '之生產',
#   '規劃',
#   '有亞洲',
#   '水為',
#   '深足',
#   '唯一',
#   '全台',
#   '海洋',
#   '全年',
#   '最大'],
#  ['營養',
#   '當調查',
#   '局位',
#   '美崙',
#   '工業區',
#   '調查局',
#   '幹員將',
#   '引領',
#   '進入',
#   '各項',
#   '鑑識',
#   '絲馬跡',
#   '調查',
#   '便當',
#   '需經過',
#   '科學',
#   '實驗',
#   '美味',
#   '安心',
#   '各位',
#   '神秘',
#   '秘密',
#   '一份',
#   '究竟',
#   '食品',
#   '核心',
#   '科技',
#   '多少',
#   '一起',
#   '分析'],
#  ['商圈',
#   '由舊',
#   '東線',
#   '鐵路',
#   '週邊',
#   '東大門',
#   '以東大門',
#   '基點',
#   '相連',
#   '銜接',
#   '伴手',
#   '禮一條',
#   '中華路',
#   '節約',
#   '舊鐵道',
#   '濃郁',
#   '氛圍',
#   '老店',
#   '夜市',
#   '新港',
#   '徒步',
#   '大禹',
#   '百年',
#   '一心',
#   '行人',
#   '文化',
#   '具有',
#   '形成'],
#  ['公園',
#   '南濱',
#   '太平洋',
#   '花蓮',
#   '北濱段',
#   '依著',
#   '規劃',
#   '地景',
#   '岸邊',
#   '大顆',
#   '石頭',
#   '可遠眺',
#   '洄瀾',
#   '新灣',
#   '連接',
#   '兩潭',
#   '車道',
#   '環境',
#   '乾淨',
#   '整片',
#   '海堤',
#   '建置',
#   '造型',
#   '海岸',
#   '自行',
#   '新月',
#   '原始',
#   '保留',
#   '包含',
#   '坐在',
#   '自然'],
#  ['一邊',
#   '緣著斷',
#   '絕壁',
#   '棧道',
#   '強化',
#   '190',
#   '僅十人',
#   '進入',
#   '腳下',
#   '萬丈',
#   '深淵',
#   '一覽',
#   '驚險',
#   '破表',
#   '底端',
#   '山景',
#   '全新',
#   '透明',
#   '玻璃',
#   '太平洋',
#   '程度',
#   '一次'],
#  ['步道',
#   '景觀',
#   '終點',
#   '步行',
#   '平台',
#   '沿著步',
#   '可抵',
#   '海灘',
#   '沿線',
#   '設置',
#   '資源',
#   '解說',
#   '系統',
#   '遊客',
#   '獲得',
#   '相關',
#   '資訊',
#   '介紹',
#   '全線',
#   '設而成',
#   '30',
#   '分鐘',
#   '抵達',
#   '遊客們',
#   '階梯',
#   '欣賞',
#   '拍岸',
#   '斷崖',
#   '宏偉',
#   '雄姿',
#   '崇德',
#   '白浪',
#   '石板',
#   '清水',
#   '即可',
#   '植物',
#   '坐在'],
#  ['步道',
#   '砂卡',
#   '太魯閣',
#   '小錐麓',
#   '步道位',
#   '外側',
#   '緊鄰',
#   '立霧',
#   '邊坡',
#   '這是',
#   '國家',
#   '公園',
#   '處闢',
#   '走小錐麓',
#   '接著',
#   '道口',
#   '直通',
#   '台地',
#   '隧道',
#   '下游',
#   '完成',
#   '管理'],
#  ['舊道',
#   '道路',
#   '蘇花',
#   '匯德',
#   '通車',
#   '擷取',
#   '改為',
#   '人車',
#   '景觀',
#   '寬闊',
#   '平緩',
#   '細細',
#   '欣賞',
#   '斷崖',
#   '海風',
#   '暢快',
#   '已規劃',
#   '為步',
#   '吹拂',
#   '美景',
#   '共用',
#   '完工',
#   '清水',
#   '隧道',
#   '原是',
#   '太平洋',
#   '享受',
#   '公路'],
#  ['部落',
#   '原住民',
#   '大禮',
#   '太魯閣族',
#   '砂卡',
#   '之間',
#   '平緩',
#   '並無',
#   '可達',
#   '大禮大',
#   '對外',
#   '聯絡',
#   '流籠',
#   '頭輸',
#   '物資',
#   '其餘端',
#   '賴雙腳',
#   '循山徑',
#   '斗及',
#   '山巒',
#   '遠離',
#   '塵囂',
#   '反璞',
#   '遺世',
#   '獨立',
#   '座落在',
#   '保留地',
#   '世外桃源',
#   '偶而',
#   '溪谷',
#   '徒步',
#   '美景',
#   '相伴',
#   '山林',
#   '大山',
#   '台地',
#   '清水',
#   '大同',
#   '天星',
#   '同步',
#   '村民',
#   '原始',
#   '享受',
#   '道路',
#   '公路',
#   '唯一',
#   '真的',
#   '生活',
#   '只有'],
#  ['一邊',
#   '緣著斷',
#   '絕壁',
#   '棧道',
#   '強化',
#   '190',
#   '僅十人',
#   '進入',
#   '腳下',
#   '萬丈',
#   '深淵',
#   '一覽',
#   '驚險',
#   '破表',
#   '底端',
#   '山景',
#   '全新',
#   '透明',
#   '玻璃',
#   '太平洋',
#   '程度',
#   '一次'],
#  ['休憩',
#   '哨角',
#   '石門',
#   '花蓮',
#   '豐濱',
#   '石門班',
#   '因原',
#   '部隊',
#   '廢棄後經',
#   '並設',
#   '小燈',
#   '雙心',
#   '愛心',
#   '裝置',
#   '距離',
#   '區約',
#   '500',
#   '一覽',
#   '360',
#   '11',
#   '線上',
#   '之處',
#   '石梯',
#   '海景',
#   '石雕',
#   '海防',
#   '雕塑',
#   '大理石',
#   '整治',
#   '所在地',
#   '前往',
#   '得名',
#   '公里',
#   '不到',
#   '重新'],
#  ['童趣',
#   '自從',
#   '黑松汽水',
#   '這拍',
#   '攝廣告',
#   '而紅',
#   '絕美',
#   '歐洲',
#   '風景',
#   '翠綠',
#   '落羽',
#   '隨著陽',
#   '光灑',
#   '現夢幻',
#   '變化',
#   '充滿',
#   '民宿',
#   '國外',
#   '遼闊',
#   '廣大',
#   '盡情',
#   '快樂',
#   '親子',
#   '時光',
#   '明信片',
#   '倒映在',
#   '一炮',
#   '青青',
#   '小朋友',
#   '置身',
#   '光影',
#   '宛如',
#   '松林',
#   '草地',
#   '奔跑',
#   '城堡',
#   '山水',
#   '一旁',
#   '般的',
#   '水中',
#   '享受'],
#  ['木瓜溪',
#   '翡翠谷',
#   '歷史',
#   '古道',
#   '秀林',
#   '鄉銅門村',
#   '對岸',
#   '慕谷',
#   '慕魚',
#   '生態',
#   '最為秀麗',
#   '風景為',
#   '沿著',
#   '太魯閣',
#   '山脈',
#   '東遷',
#   '風景',
#   '意義及',
#   '遊憩',
#   '價值',
#   '二百多年',
#   '廊道',
#   '宜人',
#   '交通要道',
#   '族人',
#   '蜿蜒',
#   '光景',
#   '而行',
#   '河谷',
#   '早期',
#   '中央',
#   '具有'],
#  ['碧赫潭',
#   '攔水堤',
#   '大加',
#   '部落',
#   '山泉水',
#   '隱身',
#   '萬榮',
#   '秘境',
#   '這片',
#   '頭目碧赫',
#   '捐地並',
#   '潰堤',
#   '由碧赫',
#   '並將',
#   '池潭',
#   '瓦利斯',
#   '私房',
#   '接引',
#   '挖土',
#   '水潭',
#   '池塘',
#   '改建',
#   '田地',
#   '命名',
#   '注入'],
#  ['日據',
#   '時期',
#   '吉拉',
#   '阿美族',
#   '米代',
#   '花蓮縣',
#   '富里',
#   '為主',
#   '傳統',
#   '接觸',
#   '種植技術',
#   '種植',
#   '米種',
#   '因品',
#   '質極佳',
#   '進貢',
#   '南村',
#   '旱稻',
#   '最南端',
#   '御用',
#   '天皇',
#   '原先',
#   '作物',
#   '清朝',
#   '水稻',
#   '部落',
#   '居民'],
#  ['濕地',
#   '玉里',
#   '景觀',
#   '啟模',
#   '公園',
#   '美麗寧靜',
#   '生態',
#   '攝影',
#   '遊客',
#   '前來',
#   '地屬',
#   '範圍',
#   '環保局',
#   '處理',
#   '玉里鎮',
#   '廢水',
#   '營造',
#   '玩家',
#   '大自然',
#   '原是',
#   '吸引',
#   '所以'],
#  ['自創',
#   '82',
#   '邱金鳳',
#   '阿嬤親',
#   '手構',
#   '將農村',
#   '回憶畫',
#   '下來',
#   '南語',
#   '打油',
#   '邱阿嬤靠',
#   '自學書',
#   '法學會',
#   '而牆',
#   '字體',
#   '遊客邊',
#   '看畫',
#   '邊猜',
#   '充滿',
#   '拼接',
#   '趣味',
#   '搭配',
#   '文字',
#   '故事',
#   '甚至'],
#  ['湖村', '瀑布', '豐鄉', '樹湖', '隱密', '當地', '多稱', '座落在', '山林', '居民', '之中', '所以'],
#  ['園區',
#   '南華',
#   '廠房',
#   '南華林業',
#   '公園',
#   '林務局',
#   '儲木場',
#   '1987',
#   '作業',
#   '結束',
#   '為止',
#   '當年',
#   '機具',
#   '剖木機',
#   '機車頭',
#   '運材',
#   '鐵道',
#   '維持',
#   '外則',
#   '儲木池',
#   '原貌',
#   '工作站',
#   '仍然',
#   '伐木',
#   '偌大',
#   '宣告',
#   '所在地',
#   '保存',
#   '森林',
#   '早期',
#   '直到',
#   '文化',
#   '使用'],
#  ['建物',
#   '陽光',
#   '電城位',
#   '花蓮市',
#   '東大門',
#   '當時',
#   '新台幣',
#   '億餘元',
#   '補助',
#   '鋼構',
#   '1000',
#   '太陽',
#   '能板',
#   '多片',
#   '夜市',
#   '上方',
#   '中央'],
#  ['親水公園',
#   '空間',
#   '水源',
#   '一千二',
#   '隸屬',
#   '生態',
#   '龍泉',
#   '佰坪',
#   '佳山',
#   '聯絡',
#   '農地',
#   '舊時',
#   '而開',
#   '發現',
#   '引進',
#   '開發為',
#   '休閒親',
#   '水公園',
#   '將周邊',
#   '進行',
#   '種植',
#   '規劃',
#   '設計生',
#   '態溝',
#   '吊橋',
#   '親水階梯',
#   '活動',
#   '休憩',
#   '深井',
#   '道旁',
#   '水生植物',
#   '美化',
#   '坐落',
#   '占地',
#   '充沛',
#   '灌溉',
#   '意外',
#   '不但',
#   '位置',
#   '需要'],
#  ['展演',
#   '郭子究',
#   '音樂',
#   '經營',
#   '體驗',
#   '空間',
#   '規劃',
#   '主軸有',
#   '二個',
#   '相關',
#   '設施',
#   '強調',
#   '可區',
#   '分為',
#   '社區',
#   '互動',
#   '活動',
#   '藝文',
#   '項目',
#   '文化',
#   '功能性',
#   '其一',
#   '四大',
#   '大致',
#   '方向'],
#  ['七七',
#   '高地',
#   '過去',
#   '軍事',
#   '極少',
#   '數遊',
#   '客會',
#   '地勢',
#   '絕美',
#   '環景',
#   '360',
#   '看山',
#   '看海',
#   '俯覽',
#   '市區',
#   '視野',
#   '景點',
#   '77',
#   '海拔高度',
#   '要塞',
#   '景色',
#   '不高',
#   '地方'],
#  ['宿舍',
#   '營所通',
#   '中正',
#   '溪畔',
#   '美崙',
#   '花蓮市',
#   '橋旁',
#   '這個',
#   '群在',
#   '時代',
#   '花蓮港分',
#   '屯大隊',
#   '軍官',
#   '群內',
#   '一條',
#   '通過筑',
#   '紫橋',
#   '右側',
#   '社區',
#   '日式',
#   '斜坡',
#   '住宿',
#   '下方',
#   '原本',
#   '日本',
#   '提供'],
#  ['農場',
#   '有趣',
#   '星巴克',
#   '台開心',
#   '騎馬',
#   '食動物',
#   '公雞',
#   '天鵝等',
#   '季節',
#   '還會',
#   '參觀',
#   '寵物',
#   '帶來',
#   '時間',
#   '小時',
#   '結束後還',
#   '接續',
#   '開心',
#   '景點',
#   '貨櫃',
#   '新天堂',
#   '樂園',
#   '整片',
#   '梅花鹿',
#   '向日葵',
#   '孔雀',
#   '限定',
#   '停留']]

# %%
flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat)

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
mask = np.array(Image.open(r"C:\Users\tien\Documents\GitHub\PL\file\W9\Halian.jpg"))
font = "C:\Windows\Fonts\MSJH.TTC"

# %%
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)

# %%
plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
