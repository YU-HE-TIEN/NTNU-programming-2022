# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\tien\Documents\GitHub\PL\file\W8\number_of_tourists_statistics.csv",index_col=0)
data.head()
# Out:
#      年別    類型    觀光遊憩區       細分  縣市別        1月        2月        3月       4月  \
# 0  2012  國家公園  陽明山國家公園  陽明山遊客中心  臺北市   12187.0   18612.0   18580.0  13329.0
# 1  2012  國家公園  陽明山國家公園     陽明書屋  臺北市    2597.0    3617.0    5221.0   4317.0
# 2  2012  國家公園  陽明山國家公園     陽明公園  臺北市  161000.0  463000.0  705200.0  85600.0
# 3  2012  國家公園  陽明山國家公園    大屯遊憩區  臺北市   17047.0   29079.0   38558.0  34332.0
# 4  2012  國家公園  陽明山國家公園   龍鳳谷遊憩區  臺北市   21201.0   22134.0   62447.0  64691.0
#
#         5月       6月       7月       8月       9月      10月      11月      12月  \
# 0  14179.0  11397.0  16000.0  11791.0  10469.0  11515.0   6896.0   9631.0
# 1   3497.0   2815.0   3005.0   2497.0   2764.0   3701.0   2863.0   2983.0
# 2  38600.0  28000.0  51700.0  44700.0  39000.0  36000.0  35000.0  33000.0
# 3  43906.0  42586.0  63721.0  41881.0  51743.0  38214.0  27467.0  27306.0
# 4  16243.0  15811.0  15787.0  16963.0  16176.0  18951.0  18136.0  19135.0
#
#         合計
# 0   154586
# 1    39877
# 2  1720800
# 3   455840
# ...

# %%
print("資料(資料筆數,欄位數量): ",data.shape)
print("資料中所有欄位名稱: ",data.columns)
print("資料中是否有空值: ",data.empty)
# Out:
# 資料(資料筆數,欄位數量):  (3065, 18)
# 資料中所有欄位名稱:  Index(['年別', '類型', '觀光遊憩區', '細分', '縣市別', '1月', '2月', '3月', '4月', '5月', '6月',
#        '7月', '8月', '9月', '10月', '11月', '12月', '合計'],
#       dtype='object')
# 資料中是否有空值:  False

# %%
set(data["類型"])
# Out:
# {'休閒農業區及休閒農場',
#  '其他',
#  '博物館',
#  '國家公園',
#  '國家級風景特定區',
#  '宗教場所',
#  '森林遊樂區',
#  '直轄市及縣(市)級風景特定區',
#  '觀光地區'}

# %%
set(data["觀光遊憩區"])
# Out:
# {' -',
#  '-',
#  '北海岸及觀音山國家風景區',
#  '參山國家風景區',
#  '墾丁國家公園',
#  '大鵬灣國家風景區',
#  '太魯閣國家公園',
#  '日月潭國家風景區',
#  '東北角暨宜蘭海岸國家風景區',
#  '東部海岸國家風景區',
#  '澎湖國家風景區',
#  '玉山國家公園',
#  '花東縱谷國家風景區',
#  '茂林國家風景區',
#  '西拉雅國家風景區',
#  '金門國家公園',
#  '阿里山國家風景區',
#  '陽明山國家公園',
#  '雪霸國家公園',
#  '雲嘉南濱海國家風景區',
#  '馬祖國家風景區'}

# %%
c = (data["類型"] == "國家公園")
c
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3060    False
# 3061    False
# 3062    False
# 3063    False
# 3064    False
# Name: 類型, Length: 3065, dtype: bool

# %%
d = data[c]
d.head()
# Out:
#      年別    類型    觀光遊憩區       細分  縣市別        1月        2月        3月       4月  \
# 0  2012  國家公園  陽明山國家公園  陽明山遊客中心  臺北市   12187.0   18612.0   18580.0  13329.0
# 1  2012  國家公園  陽明山國家公園     陽明書屋  臺北市    2597.0    3617.0    5221.0   4317.0
# 2  2012  國家公園  陽明山國家公園     陽明公園  臺北市  161000.0  463000.0  705200.0  85600.0
# 3  2012  國家公園  陽明山國家公園    大屯遊憩區  臺北市   17047.0   29079.0   38558.0  34332.0
# 4  2012  國家公園  陽明山國家公園   龍鳳谷遊憩區  臺北市   21201.0   22134.0   62447.0  64691.0
#
#         5月       6月       7月       8月       9月      10月      11月      12月  \
# 0  14179.0  11397.0  16000.0  11791.0  10469.0  11515.0   6896.0   9631.0
# 1   3497.0   2815.0   3005.0   2497.0   2764.0   3701.0   2863.0   2983.0
# 2  38600.0  28000.0  51700.0  44700.0  39000.0  36000.0  35000.0  33000.0
# 3  43906.0  42586.0  63721.0  41881.0  51743.0  38214.0  27467.0  27306.0
# 4  16243.0  15811.0  15787.0  16963.0  16176.0  18951.0  18136.0  19135.0
#
#         合計
# 0   154586
# 1    39877
# 2  1720800
# 3   455840
# ...

# %%
c = (data["類型"] == "國家公園")
d = data[c]

print("共有",len(d),"筆資料")
# Out:
# 共有 372 筆資料

# %%
#篩選資料:多條件
c1 = (data["類型"] == "國家公園") & (data["觀光遊憩區"] == "玉山國家公園")
d1 = data[c1]

print("共有",len(d1),"筆資料")
d1.head()
# Out:
# 共有 50 筆資料
#       年別    類型   觀光遊憩區           細分  縣市別       1月       2月       3月       4月  \
# 6   2012  國家公園  玉山國家公園       塔塔加遊憩區  南投縣  83806.0  59526.0  63451.0  71541.0
# 7   2012  國家公園  玉山國家公園       梅山遊客中心  高雄市   4846.0   1854.0   1190.0   1849.0
# 8   2012  國家公園  玉山國家公園       南安遊客中心  花蓮縣  37578.0  19373.0  21987.0  20037.0
# 9   2012  國家公園  玉山國家公園  玉山管理處遊客服務中心  南投縣  13262.0   9460.0   9322.0  10362.0
# 10  2012  國家公園  玉山國家公園         排雲山莊  南投縣    371.0     80.0    376.0   1476.0
#
#          5月       6月       7月       8月       9月      10月      11月      12月  \
# 6   64384.0  19312.0  34755.0  17392.0  25217.0  39252.0  53688.0  50449.0
# 7    1092.0      0.0      0.0      0.0      6.0    651.0     27.0     19.0
# 8   18384.0  12088.0  24176.0  16894.0  23817.0  22601.0  23157.0  20602.0
# 9   10233.0  10338.0  13533.0  10098.0   9042.0   9670.0  10719.0  16931.0
# 10   1511.0    979.0   1868.0    643.0   1548.0   2128.0   2173.0    966.0
#
#         合計
# 6   582773
# 7    11534
# ...

# %%
#資料名稱.loc[行標籤,列標籤]
loc1 = data.loc[50:55,["類型","觀光遊憩區","細分"]]
loc1
# Out:
#           類型          觀光遊憩區        細分
# 50  國家級風景特定區  東北角暨宜蘭海岸國家風景區    福隆蔚藍海岸
# 51  國家級風景特定區   北海岸及觀音山國家風景區    野柳地質公園
# 52  國家級風景特定區   北海岸及觀音山國家風景區       白沙灣
# 53  國家級風景特定區   北海岸及觀音山國家風景區  翡翠灣濱海遊憩區
# 54  國家級風景特定區   北海岸及觀音山國家風景區       觀音山
# 55  國家級風景特定區   北海岸及觀音山國家風景區   情人湖及湖海灣

# %%
#資料名稱.iloc[行索引,列索引]
iloc1 = data.iloc[50:56,0:3]
iloc1
# Out:
#       年別        類型          觀光遊憩區
# 50  2012  國家級風景特定區  東北角暨宜蘭海岸國家風景區
# 51  2012  國家級風景特定區   北海岸及觀音山國家風景區
# 52  2012  國家級風景特定區   北海岸及觀音山國家風景區
# 53  2012  國家級風景特定區   北海岸及觀音山國家風景區
# 54  2012  國家級風景特定區   北海岸及觀音山國家風景區
# 55  2012  國家級風景特定區   北海岸及觀音山國家風景區

# %%
iloc2 = data.iloc[ [50,52,54] , [1,3,5] ]
iloc2
# Out:
#           類型      細分       1月
# 50  國家級風景特定區  福隆蔚藍海岸   1484.0
# 52  國家級風景特定區     白沙灣  14411.0
# 54  國家級風景特定區     觀音山  34082.0

# %%
r1=data["觀光遊憩區"].str.contains("玉山")
data[r1]
# Out:
#         年別    類型   觀光遊憩區           細分  縣市別       1月        2月       3月  \
# 6     2012  國家公園  玉山國家公園       塔塔加遊憩區  南投縣  83806.0   59526.0  63451.0
# 7     2012  國家公園  玉山國家公園       梅山遊客中心  高雄市   4846.0    1854.0   1190.0
# 8     2012  國家公園  玉山國家公園       南安遊客中心  花蓮縣  37578.0   19373.0  21987.0
# 9     2012  國家公園  玉山國家公園  玉山管理處遊客服務中心  南投縣  13262.0    9460.0   9322.0
# 10    2012  國家公園  玉山國家公園         排雲山莊  南投縣    371.0      80.0    376.0
# 293   2013  國家公園  玉山國家公園       塔塔加遊憩區  南投縣  58010.0  102555.0  63474.0
# 294   2013  國家公園  玉山國家公園       梅山遊客中心  高雄市   1066.0    3507.0    956.0
# 295   2013  國家公園  玉山國家公園       南安遊客中心  花蓮縣  22651.0   41887.0  22030.0
# 296   2013  國家公園  玉山國家公園  玉山管理處遊客服務中心  南投縣  14978.0    9523.0   9128.0
# 297   2013  國家公園  玉山國家公園         排雲山莊  南投縣    464.0      29.0   1232.0
# 580   2014  國家公園  玉山國家公園       塔塔加遊憩區  南投縣  23433.0   45814.0  61971.0
# 581   2014  國家公園  玉山國家公園       梅山遊客中心  高雄市   1569.0    3280.0   1943.0
# ...

# %%
print("共有",len(data[r1]),"筆資料")
# Out:
# 共有 50 筆資料

# %%
a = data["類型"][50]
a
# Out:
# '國家級風景特定區'

# %%
print(a)
print(type(a))
# Out:
# 國家級風景特定區
# <class 'str'>

# %%
number = 3
number1 = " number + 7 "
print(type(number1))
# Out:
# <class 'str'>

# %%
print(eval(number1))
# Out:
# 10

# %%
print(type(eval(number1)))
# Out:
# <class 'int'>

# %%
city = []
for i in data["縣市別"]:
    city.append(i)
data["縣市別"] = city
data.head()
# Out:
#      年別    類型    觀光遊憩區       細分  縣市別        1月        2月        3月       4月  \
# 0  2012  國家公園  陽明山國家公園  陽明山遊客中心  臺北市   12187.0   18612.0   18580.0  13329.0
# 1  2012  國家公園  陽明山國家公園     陽明書屋  臺北市    2597.0    3617.0    5221.0   4317.0
# 2  2012  國家公園  陽明山國家公園     陽明公園  臺北市  161000.0  463000.0  705200.0  85600.0
# 3  2012  國家公園  陽明山國家公園    大屯遊憩區  臺北市   17047.0   29079.0   38558.0  34332.0
# 4  2012  國家公園  陽明山國家公園   龍鳳谷遊憩區  臺北市   21201.0   22134.0   62447.0  64691.0
#
#         5月       6月       7月       8月       9月      10月      11月      12月  \
# 0  14179.0  11397.0  16000.0  11791.0  10469.0  11515.0   6896.0   9631.0
# 1   3497.0   2815.0   3005.0   2497.0   2764.0   3701.0   2863.0   2983.0
# 2  38600.0  28000.0  51700.0  44700.0  39000.0  36000.0  35000.0  33000.0
# 3  43906.0  42586.0  63721.0  41881.0  51743.0  38214.0  27467.0  27306.0
# 4  16243.0  15811.0  15787.0  16963.0  16176.0  18951.0  18136.0  19135.0
#
#         合計
# 0   154586
# 1    39877
# 2  1720800
# 3   455840
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       2 for i in data["縣市別"]:
#       3     if i=='宜蘭縣':
# ----> 4         date1.append(i)
#       5 data1v= pd.DataFrame(data1)
#
# NameError: name 'date1' is not defined
